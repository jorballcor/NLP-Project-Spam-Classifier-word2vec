# %%
import pandas as pd
dataset = pd.read_csv(
    'sms+spam+collection\SMSSpamCollection', 
    sep='\t',
    names=["label", "message"]
    )
dataset
# Out:
#      label                                            message
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...
# ...    ...                                                ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...
# 5568   ham               Will ü b going to esplanade fr home?
# 5569   ham  Pity, * was in mood for that. So...any other s...
# 5570   ham  The guy did some bitching but I acted like i'd...
# 5571   ham                         Rofl. Its true to its name
#
# [5572 rows x 2 columns]

# %%
dataset['message'].loc[100]
# Out:
# "Please don't text me anymore. I have nothing else to say."

# %%
messages = dataset['message']

# %%
import string
import nltk

# %%
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer

# %%
ss = SnowballStemmer('english')
stop_words_EN = set(stopwords.words('english'))

# %%
corpus = []
for i in range(len(messages)):
    messages[i] = messages[i].lower().translate(str.maketrans('', '', string.punctuation))
    words = nltk.word_tokenize(messages[i])
    words = [ss.stem(word) for word in words if word not in stop_words_EN]
    messages[i] = ' '.join(words)
    corpus.append(messages[i])

# %%
messages[100]
# Out:
# 'pleas dont text anymor noth els say'

# %%
corpus
# Out:
# ['go jurong point crazi avail bugi n great world la e buffet cine got amor wat',
#  'ok lar joke wif u oni',
#  'free entri 2 wkli comp win fa cup final tkts 21st may 2005 text fa 87121 receiv entri questionstd txt ratetc appli 08452810075over18',
#  'u dun say ear hor u c alreadi say',
#  'nah dont think goe usf live around though',
#  'freemsg hey darl 3 week word back id like fun still tb ok xxx std chgs send £150 rcv',
#  'even brother like speak treat like aid patent',
#  'per request mell mell oru minnaminungint nurungu vettam set callertun caller press 9 copi friend callertun',
#  'winner valu network custom select receivea £900 prize reward claim call 09061701461 claim code kl341 valid 12 hour',
#  'mobil 11 month u r entitl updat latest colour mobil camera free call mobil updat co free 08002986030',
#  'im gon na home soon dont want talk stuff anymor tonight k ive cri enough today',
#  'six chanc win cash 100 20000 pound txt csh11 send 87575 cost 150pday 6day 16 tsandc appli repli hl 4 info',
#  'urgent 1 week free membership £100000 prize jackpot txt word claim 81010 tc wwwdbuknet lccltd pobox 4403ldnw1a7rw18',
#  'ive search right word thank breather promi wont take help grant fulfil promi wonder bless time',
#  'date sunday',
#  'xxxmobilemovieclub use credit click wap link next txt messag click httpwap xxxmobilemovieclubcomnqjkgighjjgcbl',
#  'oh kim watch',
#  'eh u rememb 2 spell name yes v naughti make v wet',
#  'fine that\x92 way u feel that\x92 way gota b',
#  'england v macedonia dont miss goalsteam news txt ur nation team 87077 eg england 87077 trywal scotland 4txtú120 poboxox36504w45wq 16',
#  'serious spell name',
#  '‘ go tri 2 month ha ha joke',
#  'ü pay first lar da stock comin',
#  'aft finish lunch go str lor ard 3 smth lor u finish ur lunch alreadi',
#  'ffffffffff alright way meet sooner',
#  'forc eat slice im realli hungri tho suck mark get worri know im sick turn pizza lol',
#  'lol alway convinc',
#  'catch bus fri egg make tea eat mom left dinner feel love',
#  'im back amp pack car ill let know room',
#  'ahhh work vagu rememb feel like lol',
#  'wait still clear sure sarcast x doesnt want live us',
#  'yeah got 2 v apologet n fallen actin like spoilt child got caught till 2 wont go bad cheer',
#  'k tell anyth',
#  'fear faint housework quick cuppa',
#  'thank subscript rington uk mobil charg £5month plea confirm repli yes repli charg',
#  'yup ok go home look time msg ü xuhui go learn 2nd may lesson 8am',
#  'oop ill let know roommat done',
#  'see letter b car',
#  'anyth lor u decid',
#  'hello saturday go text see youd decid anyth tomo im tri invit anyth',
#  'pls go ahead watt want sure great weekend abiola',
#  'forget tell want need crave love sweet arabian steed mmmmmm yummi',
#  '07732584351 rodger burn msg tri call repli sms free nokia mobil free camcord plea call 08000930705 deliveri tomorrow',
#  'see',
#  'great hope like man well endow ltgt inch',
#  'callsmessagesmiss call',
#  'didnt get hep b immuni nigeria',
#  'fair enough anyth go',
#  'yeah hope tyler cant could mayb ask around bit',
#  'u dont know stubborn didnt even want go hospit kept tell mark im weak sucker hospit weak sucker',
#  'think first time saw class',
#  'gram usual run like ltgt half eighth smarter though get almost whole second gram ltgt',
#  'k fyi x ride ear tomorrow morn hes crash place tonight',
#  'wow never realiz embarass accomod thought like sinc best could alway seem happi cave im sorri didnt dont give im sorri offer im sorri room embarass',
#  'sms ac sptv new jersey devil detroit red wing play ice hockey correct incorrect end repli end sptv',
#  'know mallika sherawat yesterday find lturlgt',
#  'congrat 1 year special cinema pass 2 call 09061209465 c suprman v matrix3 starwars3 etc 4 free bx420ip45w 150pm dont miss',
#  'sorri ill call later meet',
#  'tell reach',
#  'yesgauti sehwag odi seri',
#  'gon na pick 1 burger way home cant even move pain kill',
#  'ha ha ha good joke girl situat seeker',
#  'part check iq',
#  'sorri roommat took forev ok come',
#  'ok lar doubl check wif da hair dresser alreadi said wun cut v short said cut look nice',
#  'valu custom plea advi follow recent review mob award £1500 bonus prize call 09066364589',
#  'today song dedic day song u dedic send ur valuabl frnds first rpli',
#  'urgent ur award complimentari trip eurodisinc trav acoentry41 £1000 claim txt dis 87121 186£150morefrmmob shracomorsglsuplt10 ls1 3aj',
#  'hear new divorc barbi come ken stuff',
#  'plane give month end',
#  'wah lucki man save money hee',
#  'finish class',
#  'hi babe im home wan na someth xx',
#  'kkwhere youhow perform',
#  'u call',
#  'wait machan call free',
#  'cool gentleman treat digniti respect',
#  'like peopl much shi pa',
#  'oper ltgt',
#  'still look job much tas earn',
#  'sorri ill call later',
#  'k call ah',
#  'ok way home hi hi',
#  'place man',
#  'yup next stop',
#  'call later dont network urgnt sms',
#  'real u get yo need 2 ticket one jacket im done alreadi use multi',
#  'yes start send request make pain came back im back bed doubl coin factori got ta cash nitro',
#  'im realli still tonight babe',
#  'ela kanoil download come wen ur free',
#  'yeah ‘ stand close tho ‘ catch someth',
#  'sorri pain ok meet anoth night spent late afternoon casualti mean havent done stuff42moro includ time sheet sorri',
#  'smile pleasur smile pain smile troubl pour like rain smile sum1 hurt u smile becoz someon still love see u smile',
#  'plea call custom servic repr 0800 169 6031 10am9pm guarant £1000 cash £5000 prize',
#  'havent plan buy later check alreadi lido got 530 show e afternoon u finish work alreadi',
#  'free rington wait collect simpli text password mix 85069 verifi get usher britney fml po box 5249 mk17 92h 450ppw 16',
#  'watch telugu moviewat abt u',
#  'see finish load loan pay',
#  'hi wk ok hol yes bit run forgot hairdress appoint four need get home n shower beforehand caus prob u',
#  'see cup coff anim',
#  'plea dont text anymor noth el say',
#  'okay name ur price long legal wen pick u ave x xx',
#  'im still look car buy gone 4the drive test yet',
#  'per request mell mell oru minnaminungint nurungu vettam set callertun caller press 9 copi friend callertun',
#  'wow right didnt mean guess gave boston men chang search locat nyc someth chang cuz signin page still say boston',
#  'umma life vava umma love lot dear',
#  'thank lot wish birthday thank make birthday truli memor',
#  'aight ill hit get cash',
#  'would ip address test consid comput isnt minecraft server',
#  'know grumpi old peopl mom like better lie alway one play joke',
#  'dont worri guess hes busi',
#  'plural noun research',
#  'go dinnermsg',
#  'im ok wif cos like 2 tri new thing scare u dun like mah cos u said loud',
#  'gent tri contact last weekend draw show £1000 prize guarant call 09064012160 claim code k52 valid 12hrs 150ppm',
#  'wa ur openin sentenc formal anyway im fine juz tt im eatin much n puttin weighthaha anythin special happen',
#  'enter cabin pa said happi bday boss felt special askd 4 lunch lunch invit apart went',
#  'winner u special select 2 receiv £1000 4 holiday flight inc speak live oper 2 claim 0871277810910pmin 18',
#  'goodo yes must speak friday eggpotato ratio tortilla need',
#  'hmmmi uncl inform hes pay school direct pls buy food',
#  'privat 2004 account statement 07742676969 show 786 unredeem bonus point claim call 08719180248 identifi code 45239 expir',
#  'urgent mobil award £2000 bonus caller prize 5903 final tri contact u call landlin 09064019788 box42wr29c 150ppm',
#  'new address applespairs malarki',
#  'today voda number end 7548 select receiv 350 award match plea call 08712300220 quot claim code 4041 standard rate app',
#  'go sao mu today done 12',
#  'ü predict wat time üll finish buy',
#  'good stuff',
#  'knowyetund hasnt sent money yet sent text bother send dont involv anyth shouldnt impo anyth first place apolog',
#  'room',
#  'hey girl r u hope u r well del r bak long time c give call sum time lucyxx',
#  'kkhow much cost',
#  'im home',
#  'dear call tmorrowpl accomod',
#  'first answer question',
#  'sunshin quiz wkli q win top soni dvd player u know countri algarv txt ansr 82277 £150 sptyron',
#  'want 2 get laid tonight want real dog locat sent direct 2 ur mob join uk largest dog network bt txting gravel 69888 nt ec2a 31pmsg150p',
#  'haf msn yijuehotmailcom',
#  'call meet',
#  'check room befor activ',
#  'youll rcv msgs chat svc free hardcor servic text go 69988 u get noth u must age verifi yr network tri',
#  'got c lazi type forgot ü lect saw pouch like v nice',
#  'k text way',
#  'sir wait mail',
#  'swt thought nver get tire littl thing 4 lovabl person cozsomtim littl thing occupi biggest part heart gud ni8',
#  'know pls open back',
#  'yes see ya dot',
#  'staff name take class us',
#  'freemsg havent repli text im randi sexi femal live local luv hear u netcollex ltd 08700621170150p per msg repli stop end',
#  'ummmawil call check inour life begin qatar pls pray hard',
#  'ki delet contact',
#  'sindu got job birla soft',
#  'wine flow im never',
#  'yup thk cine better cos need 2 go 2 plaza mah',
#  'ok ur typic repli',
#  'per request mell mell oru minnaminungint nurungu vettam set callertun caller press 9 copi friend callertun',
#  'everywh dirt floor window even shirt sometim open mouth come flow dream world without half chore time joy lot tv show ill see guess like thing must exist like rain hail mist time done becom one',
#  'aaooooright work',
#  'im leav hous',
#  'hello love get interview today happi good boy think mear miss',
#  'custom servic annonc new year deliveri wait plea call 07046744435 arrang deliveri',
#  'winner u special select 2 receiv £1000 cash 4 holiday flight inc speak live oper 2 claim 0871277810810',
#  'keep safe need miss alreadi envi everyon see real life',
#  'new car hous parentsi new job hand',
#  'im love im excit day spend make happi',
#  'pls stop bootyd 32f invit friend repli yes434 no434 see wwwsmsacubootyd stop send stop frnd 62468',
#  'bangbab ur order way u receiv servic msg 2 download ur content u goto wap bangb tv ur mobil internetserv menu',
#  'place ur point e cultur modul alreadi',
#  'urgent tri contact last weekend draw show £900 prize guarant call 09061701939 claim code s89 valid 12hrs',
#  'hi frnd best way avoid missunderstd wit belov one',
#  'great escap fanci bridg need lager see tomo',
#  'yes complet formclark also utter wast',
#  'sir need axi bank account bank address',
#  'hmmm thk sure got time hop ard ya go 4 free abt muz call u discuss liao',
#  'time come later',
#  'bloodi hell cant believ forgot surnam mr ill give u clue spanish begin',
#  'well im gon na finish bath goodfin night',
#  'let know youv got money carlo make call',
#  'u still go mall',
#  'turn friend stay whole show wont back til ltgt feel free go ahead smoke ltgt worth',
#  'text doesnt repli let know log',
#  'hi spoke maneesha v wed like know satisfi experi repli toll free yes',
#  'lift hope offer money need especi end month approach hurt studi anyway gr8 weekend',
#  'lol u trust',
#  'ok gentleman treat digniti respect',
#  'guy close',
#  'go noth greatbi',
#  'hello handsom find job lazi work toward get back net mummi boytoy miss',
#  'haha awesom minut',
#  'plea call custom servic repr freephon 0808 145 4742 9am11pm guarant £1000 cash £5000 prize',
#  'got xmas radio time get',
#  'jus reach home go bath first sis use net tell u finish k',
#  'uniqu enough find 30th august wwwareyouuniquecouk',
#  'im sorri ive join leagu peopl dont keep touch mean great deal friend time even great person cost great week',
#  'hi final complet cour',
#  'stop howev suggest stay someon abl give everi stool',
#  'hope youv settl new school year wishin gr8 day',
#  'gud mrng dear hav nice day',
#  'u got person stori',
#  'hamster dead hey tmr meet 1pm orchard mrt',
#  'hi kate even hope see tomorrow bit bloodi babyjontet txt back u xxx',
#  'found enc ltgt',
#  'sent ltgt buck',
#  'hello darlin ive finish colleg txt u finish u love kate xxx',
#  'account refil success inr ltdecimalgt keralacircl prepaid account balanc rs ltdecimalgt transact id kr ltgt',
#  'goodmorn sleep ga',
#  'u call alter 11 ok',
#  'ü say like dat dun buy ericsson oso oredi lar',
#  'enter cabin pa said happi bday boss felt special askd 4 lunch lunch invit apart went',
#  'aight yo dat straight dogg',
#  'plea give us connect today ltdecimalgt refund bill',
#  'shoot big load get readi',
#  'bruv hope great break reward semest',
#  'home alway chat',
#  'kkgoodstudi well',
#  'yup ü noe leh',
#  'sound great home',
#  'final match head toward draw predict',
#  'tire havent slept well past night',
#  'easi ahsen got select mean good',
#  'take exam march 3',
#  'yeah think use gt atm regist sure anyway help let know sure readi',
#  'ok prob take ur time',
#  'os call ubandu run without instal hard diskyou use os copi import file system give repair shop',
#  'sorri ill call later',
#  'u say leh cour noth happen lar say v romant jus bit lor thk e nite sceneri nice leh',
#  '500 new mobil 2004 must go txt nokia 89545 collect todayfrom £1 www4tcbiz 2optout 08718726270150gbpmtmsg18',
#  'would realli appreci call need someon talk',
#  'u meet ur dream partner soon ur career 2 flyng start 2 find free txt horo follow ur star sign e g horo ari',
#  'hey compani elama po mudyadhu',
#  'life strict teacher bcoz teacher teach lesson amp conduct exam life first conduct exam amp teach lesson happi morn',
#  'dear good morn',
#  'get gandhipuram walk cross cut road right side ltgt street road turn first right',
#  'dear go rubber place',
#  'sorri batteri die yeah im',
#  'yesher tv alway avail work place',
#  'text meet someon sexi today u find date even flirt u join 4 10p repli name age eg sam 25 18 msg recdthirtyeight penc',
#  'print oh ltgt come upstair',
#  'ill littl closer like bus stop street',
#  'youwhen wil reach',
#  'new theori argument win situat lose person dont argu ur friend kick amp say im alway correct',
#  'u 447801259231 secret admir look 2 make contact ufind rreveal think ur specialc 09058094597',
#  'tomarrow final hear laptop case cant',
#  'pleassssssseeee tel v avent done sportsx',
#  'okay shine meant sign sound better',
#  'although told u dat im baig face watch realli like e watch u gave cos fr u thanx 4 everyth dat uve done today im touch',
#  'u dont rememb old commerci',
#  'late said websit didnt dont slipper',
#  'ask call ok',
#  'kalli wont bat 2nd inning',
#  'didnt work oh ok goodnight ill fix readi time wake dear miss good night sleep',
#  'congratul ur award 500 cd voucher 125gift guarant free entri 2 100 wkli draw txt music 87066 tncs wwwldewcom1win150ppmx3age16',
#  'ranjith cal drpd deeraj deepak 5min hold',
#  'wen ur lovabl bcum angri wid u dnt take serious coz angri childish n true way show deep affect care n luv kettoda manda nice day da',
#  'doinghow',
#  '3day also ship compani take 2wks way usp take week get lag may bribe nipost get stuff',
#  'im back lem know readi',
#  'dont necessarili expect done get back though im headin',
#  'mmm yummi babe nice jolt suzi',
#  'lover need',
#  'tri contact repli offer video handset 750 anytim network min unlimit text camcord repli call 08000930705',
#  '‘ park next mini come today think',
#  'yup',
#  'anyway im go shop cos sis done yet dun disturb u liao',
#  'luton 0125698789 ring ur around h',
#  'hey realli horni want chat see nake text hot 69698 text charg 150pm unsubscrib text stop 69698',
#  'dint come us',
#  'wana plan trip sometm',
#  'sure yet still tri get hold',
#  'ur rington servic chang 25 free credit go club4mobilescom choo content stop txt club stop 87070 150pwk club4 po box1146 mk45 2wt',
#  'evo download flash jealous',
#  'rington club get uk singl chart mobil week choo top qualiti rington messag free charg',
#  'come mu sort narcot situat',
#  'night end anoth day morn come special way may smile like sunni ray leav worri blue blue bay',
#  'hmv bonus special 500 pound genuin hmv voucher answer 4 easi question play send hmv 86688 infowww100percentrealcom',
#  'usf guess might well take 1 car',
#  'object bf come',
#  'thanx',
#  'tell rob mack gf theater',
#  'awesom ill see bit',
#  'sent type food like',
#  'done hand celebr full swing yet',
#  'got call tool',
#  'wen u miss someon person definit special u person special miss keepintouch gdeve',
#  'ok ask money far',
#  'oki',
#  'yeah think usual guy still pass last night get ahold anybodi let know ill throw',
#  'k might come tonight class let ear',
#  'ok',
#  'hi babi im cruisin girl friend r u 2 give call hour home alright fone fone love jenni xxx',
#  'life mean lot love life love peopl life world call friend call world ge',
#  'dearshal mail tonitebusi streetshal updat toniteth look okvarunnathu edukkukay raksha ollubut good one real sen',
#  'hey told name gautham ah',
#  'haf u found feel stupid da v cam work',
#  'oop 4 got bit',
#  'much buzi',
#  'accid delet messag resend plea',
#  'tmobil custom may claim free camera phone upgrad pay go sim card loyalti call 0845 021 3680offer end 28thfebtc appli',
#  'unless situat go gurl would appropri',
#  'hurt tea make cri end life die plz keep one rose grave say stupid miss u nice day bslvyl',
#  'cant pick phone right pls send messag',
#  'need coff run tomoc believ time week alreadi',
#  'awesom rememb last time got somebodi high first time diesel v',
#  'shit realli shock scari cant imagin second def night u think somewh could crash night save taxi',
#  'oh way food fridg want go meal tonight',
#  'womdar actor',
#  'sms ac blind date 4u rodds1 21m aberdeen unit kingdom check httpimg sms acwicmb3cktz8r74 blind date send hide',
#  'yup remb think book',
#  'jos ask u wana meet',
#  'lol yes friendship hang thread caus u wont buy stuff',
#  'themob check newest select content game tone gossip babe sport keep mobil fit funki text wap 82468',
#  'garag key arent bookshelf',
#  'today accept dayu accept brother sister lover dear1 best1 clos1 lvblefrnd jstfrnd cutefrnd lifpartnr belovd swtheart bstfrnd rpli mean enemi',
#  'think ur smart win £200 week week quiz text play 85222 nowtc winnersclub po box 84 m26 3uz 16 gbp150week',
#  'say hell give call friend got money hes definit buy end week',
#  'hi way u 2day normal waythi real ur uniquei hope know u 4 rest mylif hope u find wot lost',
#  'made day great day',
#  'kkadvanc happi pongal',
#  'hmmm guess go 4 kb n power yoga haha dunno tahan power yoga anot thk got lo oso forgot liao',
#  'realli dude friend im afraid',
#  'decemb mobil 11mths entitl updat latest colour camera mobil free call mobil updat co free 08002986906',
#  'coff cake guess',
#  'merri christma babe love ya kiss',
#  'hey dont go watch x men lunch haha',
#  'cud u tell ppl im gona b bit l8 cos 2 buse hav gon past cos full im still waitin 4 1 pete x',
#  'would great well guild could meet bristol road somewh get touch weekend plan take flight good week',
#  'problem',
#  'callsmessagesmiss call',
#  'hi dahow today class',
#  'id say good sign well know track record read women',
#  'cool text park',
#  'im read text sent meant joke read light',
#  'kkapo kgood movi',
#  'mayb could get book tomo return immedi someth',
#  'call germani 1 penc per minut call fix line via access number 0844 861 85 85 prepay direct access',
#  'chanc might evapor soon violat privaci steal phone number employ paperwork cool plea contact report supervisor',
#  'valentin day special win £1000 quiz take partner trip lifetim send go 83600 150pmsg rcvd custcare08718720201',
#  'tadaaaaa home babe still',
#  'cool come havent wine dine',
#  'sleepingand surf',
#  'sorri ill call later',
#  'u call right call hand phone',
#  'ok great thanx lot',
#  'take post come must 1000s text happi read one wiv hello carolin end favourit bless',
#  'u hide stranger',
#  'interest like',
#  'sister clear two round birla soft yesterday',
#  'gudnitetcpract go',
#  'dis yiju jus saw ur mail case huim havent sent u num dis num',
#  'one small prestig problem',
#  'fanci shag dointerest sextextukcom txt xxuk suzi 69876 txts cost 150 per msg tncs websit x',
#  'check realli miss see jeremiah great month',
#  'nah cant help ive never iphon',
#  'car hour half im go apeshit',
#  'today sorri day ever angri ever misbehav hurt plz plz slap urself bcoz ur fault im basic good',
#  'yo guy ever figur much need alcohol jay tri figur much safe spend weed',
#  'ltgt ish minut 5 minut ago wtf',
#  'thank callingforgot say happi onam sirjii fine rememb met insur personmeet qatar insha allahrakhesh ex tata aig join tisscotay',
#  'congratul ur award 500 cd voucher 125gift guarant free entri 2 100 wkli draw txt music 87066 tncs wwwldewcom1win150ppmx3age16',
#  'ur cashbal current 500 pound maxim ur cashin send cash 86688 150pmsg cc 08708800282 hgsuite3422land roww1j6hl',
#  'im actor work work even sleep late sinc im unemploy moment alway sleep late unemploy everi day saturday',
#  'hello got st andrewsboy long way cold keep post',
#  'ha ha cool cool chikku chikkudb',
#  'oh ok prob',
#  'check audrey status right',
#  'busi tri finish new year look forward final meet',
#  'good afternoon sunshin dawn day refresh happi aliv breath air smile think love alway',
#  'well know z take care worri',
#  'updatenow xmas offer latest motorola sonyericsson nokia free bluetooth doubl min 1000 txt orang call mobileupd8 08000839402 call2optoutf4q',
#  'discount code rp176781 stop messag repli stop wwwregalportfoliocouk custom servic 08717205546',
#  'wat uniform get',
#  'cool text readi',
#  'hello boytoy geeee miss alreadi woke wish bed cuddl love',
#  'spoil bed well',
#  'im go bath msg next ltgt min',
#  'cant keep talk peopl sure pay agr price pls tell want realli buy much pay',
#  'thank rington order refer t91 charg gbp 4 per week unsubscrib anytim call custom servic 09057039994',
#  'say happen',
#  'could seen mei didt recogni face',
#  'well lot thing happen lindsay new year sigh bar ptbo blue heron someth go',
#  'keep payasam rinu bring',
#  'taught ranjith sir call sms like becaus hes verifi project prabu told today pa dont mistak',
#  'guess worri must know way bodi repair im quit sure shouldnt worri well take slow first test guid ovul relax noth youv said reason worri ill keep followin',
#  'yeah sure give coupl minut track wallet',
#  'hey leav big deal take care',
#  'hey late ah meet 945',
#  'doubl min txts 4 6month free bluetooth orang avail soni nokia motorola phone call mobileupd8 08000839402 call2optoutn9dx',
#  'took mr owl 3 lick',
#  'custom place call',
#  'mm time dont like fun',
#  '4mths half price orang line rental latest camera phone 4 free phone 11mths call mobilesdirect free 08000938767 updat or2stoptxt',
#  'yup lunch buffet u eat alreadi',
#  'huh late fr dinner',
#  'hey sat go intro pilat kickbox',
#  'morn ok',
#  'yes think offic lap room think last day didnt shut',
#  'pick bout 730ish time go',
#  'perform award calcul everi two monthnot current one month period',
#  'actual sleep still might u call back text gr8 rock sis send u text wen wake',
#  'alway put busi put pictur ass facebook one open peopl ive ever met would think pictur room would hurt make feel violat',
#  'good even sir al salam wahleykkumshar happi newsbi grace god got offer tayseertissco joinedhop fineinshah allahmeet sometimerakheshvisitor india',
#  'hmmmkbut want chang field quick dai wan na get system administr network administr',
#  'free rington text first 87131 poli text get 87131 true tone help 0845 2814032 16 1st free tone 3x£150pw e£nd txt stop',
#  'dear chechi talk',
#  'hair cream ship',
#  'none happen til get though',
#  'yep great loxahatch xmas tree burn ltgt start hour',
#  'haha get use drive usf man know lot stoner',
#  'well slight disastr class pm fav darl hope day ok coff wld good cant stay late tomorrow time place alway',
#  'hello good week fanci drink someth later',
#  'headin toward busetop',
#  'messagesom text miss sendernam miss number miss sentdat miss miss u lot everyth miss sent via fullonsmscom',
#  'come room point iron plan weekend',
#  'cos want thing',
#  'oki ill go yan jiu skip ard oso go cine den go mrt one blah blah blah',
#  'bring home wendi',
#  '100 date servic call 09064012103 box334sk38ch',
#  'whatsup dont u want sleep',
#  'alright new goal',
#  'free entri £250 week competit text word win 80086 18 tc wwwtxttowincouk',
#  'alright ill head minut text meet',
#  'send logo 2 ur lover 2 name join heart txt love name1 name2 mobno eg love adam eve 07123456789 87077 yahoo pobox36504w45wq txtno 4 ad 150p',
#  'yesfrom last week im take live call',
#  'someon contact date servic enter phone fanci find call landlin 09111032124 pobox12n146tf150p',
#  'siva hostel aha',
#  'urgent mobil number award £2000 prize guarant call 09058094455 land line claim 3030 valid 12hrs',
#  'send ur friend receiv someth ur voic speak express 1childish 2naughti 3sentiment 4rowdi 5ful attitud 6romant 7shi 8attract 9funni ltgt irrit ltgt lovabl repli',
#  'ok shell ok guess',
#  'aathiwh dear',
#  'pain urin thing el',
#  '7 esplanad ü mind give lift cos got car today',
#  'wnt buy bmw car urgentlyit vri urgentbut hv shortag ltgt lacsther sourc arng dis amt ltgt lacsthat prob',
#  'home watch tv lor',
#  'usual take fifteen fuck minut respond yes question',
#  'congrat nokia 3650 video camera phone call 09066382422 call cost 150ppm ave call 3min vari mobil 16 close 300603 post bcm4284 ldn wc1n3xx',
#  'book ticket pongal',
#  'avail im like right around hillsborough amp ltgt th',
#  'messag sent askin ltgt dollar shoul pay ltgt ltgt',
#  'ask g iouri ive told stori like ten time alreadi',
#  'long appleb fuck take',
#  'hi hope u get txtjourney hasnt gdnow 50 min late think',
#  'like love arrang',
#  'yesh realli greatbhaji told kalli best cricket sachin worldveri tough get',
#  'suppo wake gt',
#  'oic saw tot din c found group liao',
#  'sorri ill call later',
#  'hey hey wereth monkeespeopl say monkeyaround howdi gorgeous howu doin foundurself jobyet sausagelov jen xxx',
#  'sorri batteri die come im get gram place',
#  'well done blimey exerci yeah kinda rememb wot hmm',
#  'wont get concentr dear know mind everyth',
#  'lol made plan new year',
#  '10 min later k',
#  'hank lotsli',
#  'thank hope good day today',
#  'kkwhat detail want transferacc enough',
#  'ok tell stay yeah tough optimist thing improv month',
#  'loan purpo £500 £75000 homeown tenant welcom previous refus still help call free 0800 1956669 text back help',
#  'si si think ill go make oreo truffl',
#  'look ami ure beauti intellig woman like u lot know u don\x92t like like don\x92t worri',
#  'hope result consist intellig kind start ask practicum link keep ear open best ttyl',
#  '120 call cost guess isnt bad miss ya need ya want ya love ya',
#  'go thru differ feelingwav deci cope individualtim heal everyth believ',
#  'u go phone gon na die stay',
#  'great never better day give even reason thank god',
#  'upgrdcentr orang custom may claim free camera phone upgrad loyalti call 0207 153 9153 offer end 26th juli tcs appli optout avail',
#  'sorri ill call later ok bye',
#  'ok way railway',
#  'great princess love give receiv oral doggi style fave posit enjoy make love ltgt time per night',
#  'dont put stuff road keep get slipperi',
#  'go ride bike',
#  'yup need ill jus wait 4 e rain 2 stop',
#  'mani compani tell languag',
#  'okmail dear dave final notic collect 4 tenerif holiday 5000 cash award call 09061743806 landlin tcs sae box326 cw25wx 150ppm',
#  'long sinc scream princess',
#  'noth meant money enter account bank remov flat rate someon transfer ltgt account ltgt dollar got remov bank differ charg also differb sure trust 9ja person send account detail cos',
#  'want 2 get laid tonight want real dog locat sent direct 2 ur mob join uk largest dog network txting moan 69888nyt ec2a 31pmsg150p',
#  'nice line said broken heart plz dont cum 1 time infront wise trust u good 9t',
#  'ok im gon na head usf like fifteen minut',
#  'love aathilov u lot',
#  'tension ahwhat machiani problem',
#  'k pick anoth 8th done',
#  'whenr guy get back g said think stay mcr',
#  'almost see u sec',
#  'yo carlo friend alreadi ask work weekend',
#  'watch tv lor',
#  'thank babi cant wait tast real thing',
#  'chang fb jaykwon thuglyf falconerf',
#  'win realli 1 side long time',
#  'free messag activ 500 free text messag repli messag word free term condit visit www07781482378com',
#  'dear reach railway happen',
#  'depend qualiti want type sent boy fade glori 6 want ralph mayb 2',
#  'think ive fix send test messag',
#  'sorri man account dri would want could trade back half could buy shit credit card',
#  'congrat 1 year special cinema pass 2 call 09061209465 c suprman v matrix3 starwars3 etc 4 free bx420ip45w 150pm dont miss',
#  'sorryin meet ill call later',
#  'class ltgt reunion',
#  'free nowcan call',
#  'got meh',
#  'nope think go monday sorri repli late',
#  'told accentur confirm true',
#  'kate jackson rec center 7ish right',
#  'dear reach room',
#  'fight world easi u either win lose bt fightng some1 close u dificult u lose u lose u win u still lose',
#  'ü come',
#  'check nuerologist',
#  'lolnic went fish water',
#  '123 congratul week competit draw u £1450 prize claim call 09050002311 b4280703 tcsstop sms 08718727868 18 150ppm',
#  'wait e car dat bore wat cos wait outsid got noth 2 home stuff watch tv wat',
#  'mayb westshor hyde park villag place near hous',
#  'know anthoni bring money ive school fee pay rent stuff like need help friend need',
#  'signif',
#  'opinion 1 2 jada 3 kusruthi 4 lovabl 5 silent 6 spl charact 7 matur 8 stylish 9 simpl pls repli',
#  '8 latest gs still scroung ammo want give new ak tri',
#  'prabhaim sorydarealyfrm heart im sori',
#  'lol ok forgiven',
#  'nojst chang tat',
#  'guarant latest nokia phone 40gb ipod mp3 player £500 prize txt word collect 83355 ibhltd ldnw15h 150pmtmsgrcvd18',
#  'sno competit',
#  'boltblu tone 150p repli poli mono eg poly3 1 cha cha slide 2 yeah 3 slow jamz 6 toxic 8 come stop 4 tone txt',
#  'credit top httpwwwbubbletextcom renew pin tgxxrz',
#  'way transport less problemat sat night way u want ask n join bday feel free need know definit nos book fri',
#  'usual person unconsci children adult may behav abnorm ill call',
#  'ebay might less elsewh',
#  'shall come get pickl',
#  'gon na go get taco',
#  'rude campus',
#  'urgent mobil award £2000 bonus caller prize 020903 2nd attempt contact call 08718729755 box95qu',
#  'hi wont b ard 4 christma enjoy n merri xmas',
#  'today offer claim ur £150 worth discount voucher text yes 85023 savamob member offer mobil cs 08717898035 £300 sub 16 unsub repli x',
#  'yes pretti ladi like singl',
#  'reciev tone within next 24hrs term condit plea see channel u teletext pg 750',
#  'jay say doublefaggot',
#  'privat 2003 account statement 07815296484 show 800 unredeem sim point call 08718738001 identifi code 41782 expir 181104',
#  'todaysundaysunday holidayso work',
#  'gudnitetcpract go',
#  'ill late',
#  'ive call hope l8r malaria know miss guy miss bani big pls give love especi great day',
#  'good afternoon love goe day hope mayb got lead job think boytoy send passion kiss across sea',
#  'probabl gon na see later tonight lt',
#  'mayb fat finger press button doesnt know',
#  'ummmmmaah mani mani happi return day dear sweet heart happi birthday dear',
#  'tirupur da start offic call',
#  'wwwapplausestorecom monthlysubscription50pmsg max6month tcsc web age16 2stop txt stop',
#  'famous quot develop abil listen anyth uncondit without lose temper self confid mean marri',
#  'go colleg pa el ill come self pa',
#  '4 oclock mine bash flat plan',
#  'girl stay bed girl doesnt need recoveri time id rather pass fun coop bed',
#  'special',
#  'know need get hotel got invit apolog cali sweet come english bloke weddin',
#  'sorri took long omw',
#  'wait ltgt min',
#  'ok give 5 minut think see btw alibi cut hair whole time',
#  'imagin final get sink bath put pace mayb even eat left also imagin feel cage cock surround bath water remind alway enjoy cuck',
#  'hurri ive weeddefici like three day',
#  'sure get acknowledg astound tactless general faggi demand blood oath fo',
#  'ok everi night take warm bath drink cup milk youll see work magic still need loo weight know',
#  '‘ look fri pan case ‘ cheap book perhap ‘ silli fri pan ‘ like book',
#  'well uv caus mutat sunscreen like essenti theseday',
#  'lunchyou onlinewhi',
#  'know friend alreadi told',
#  'hi princess thank pic pretti',
#  'aiyo u alway c ex one dunno abt mei repli first time u repli fast lucki workin huh got bao ur sugardad ahg',
#  'hi msg meim offic',
#  'thanx 4 e browni v nice',
#  'geeeee love much bare stand',
#  'gent tri contact last weekend draw show £1000 prize guarant call 09064012160 claim code k52 valid 12hrs 150ppm',
#  'fuck babe miss alreadi know cant let send money toward net need want crave',
#  'ill call u 2mrw ninish address icki american freek wont stop callin 2 bad jen k eh',
#  'oooh bed ridden ey think',
#  'anyway go gym whatev love smile hope ok good day babe miss much alreadi',
#  'love daddi make scream pleasur go slap ass dick',
#  'wot u wan na missi',
#  'yar lor wait 4 mum 2 finish sch lunch lor whole morn stay home clean room room quit clean hee',
#  'know lab goggl went',
#  'open door',
#  'wait call',
#  'nope wait sch 4 daddi',
#  '1000 cash 2000 prize claim call09050000327',
#  'im tire argu week week want ill',
#  'ü wait 4 sch finish ard 5',
#  'mobil number £5000 claim call us back ring claim hot line 09050005321',
#  'arngd marriag u r walkin unfortunt snake bite u bt love marriag danc frnt snake amp sayin bite bite',
#  'huh ear ü dinner outsid izzit',
#  'ok anyway need chang said',
#  'tri contact repli offer 750 min 150 textand new video phone call 08002988890 repli free deliveri tomorrow',
#  'exwif abl kid want kid one day',
#  'scotland hope show jjc tendenc take care live dream',
#  'tell u headach want use 1 hour sick time',
#  'dun thk ill quit yet hmmm go jazz yogasana oso go meet em lesson den',
#  'pete plea ring meiv hard gotani credit',
#  'ya srsli better yi tho',
#  'im meet call later',
#  'ur chanc win £250 wkli shop spree txt shop 80878 tscs wwwtxt2shopcom custcar 08715705022 1x150pwk',
#  'special select receiv 2000 pound award call 08712402050 line close cost 10ppm 16 tcs appli ag promo',
#  'privat 2003 account statement 07753741225 show 800 unredeem point call 08715203677 identifi code 42478 expir 241004',
#  'still grand prix',
#  'met stranger choo friend long world stand friendship never end let friend forev gud nitz',
#  'great',
#  'gud mrng dear nice day',
#  'import custom servic announc call freephon 0800 542 0825',
#  'exhaust train morn much wine pie sleep well',
#  'im go buy mum present ar',
#  'mind blastin tsunami occur rajnik stop swim indian oceand',
#  'u send home first ok lor im readi yet',
#  'speak cash yet',
#  'happi come noon',
#  'meet lunch la',
#  'take care n get well soon',
#  'xclusiveclubsaisai 2morow 285 soir special zouk nichol parisfr rose 2 ladi info 0794674629107880867867',
#  'meant say cant wait see u get bore bridgwat banter',
#  'neva mind ok',
#  'fine imma get drink somethin want come find',
#  '22 day kick euro2004 u kept date latest news result daili remov send get txt stop 83222',
#  'valentin game send dis msg ur friend 5 answer r someon realli love u que colour suit bestrpli',
#  'mani depend',
#  'thanx4 today cer nice 2 catch ave 2 find time often oh well take care c u soonc',
#  'call said himthen choo futur',
#  'happi valentin day know ear hundr handsom beauti wish thought finish aunti uncl 1st',
#  'like v shock leh cos tell shuhui like tell leona also like dat almost know liao got ask abt ur reaction lor',
#  'famili happi',
#  'come n pick ü come immedi aft ur lesson',
#  'let snow let snow kind weather bring ppl togeth friendship grow',
#  'dear got ltgt dollar hi hi',
#  'good word word may leav u dismay mani time',
#  'make sure alex know birthday fifteen minut far concern',
#  'sorri got thing may pub later',
#  'nah straight bring bud drink someth actual littl use straight cash',
#  'haha good hear im offici paid market 8th',
#  'mani lick take get center tootsi pop',
#  'yup thk r e teacher said make face look longer darren ask 2 cut short',
#  'new textbuddi chat 2 horni guy ur area 4 25p free 2 receiv search postcod gaytextbuddycom txt one name 89693',
#  'today vodafon number end 4882 select receiv £350 award number match call 09064019014 receiv £350 award',
#  'plea dont say like hi hi hi',
#  'thank u',
#  'oh forward messag thought send',
#  'got seventeen pound seven hundr ml – hope ok',
#  'dear voucher holder 2 claim week offer pc go httpwwwetlpcoukexpressoff tscs apply2 stop text txt stop 80062',
#  'n funni',
#  'sweetheart hope kind day one load reason smile biola',
#  'ü login dat time dad fetch ü home',
#  'shower babi',
#  'askd u question hour answer',
#  'well imma definit need restock thanksgiv ill let know im',
#  'said kiss kiss cant sound effect gorgeous man isnt kind person need smile brighten day',
#  'probabl gon na swing wee bit',
#  'ya nice readi thursday',
#  'allo brave buse taken train triumph mean ‘ b ‘ ham jolli good rest week',
#  'watch cartoon listen music amp eve go templ amp church u',
#  'mind ask happen dont say uncomfort',
#  'privat 2003 account statement show 800 unredeem point call 08715203694 identifi code 40533 expir 311004',
#  'prob send email',
#  '1000 cash 2000 prize claim call09050000327 tc rstm sw7 3ss 150ppm',
#  'cool sometim slow gentl sonetim rough hard',
#  'im gon na say sorri would normal start panic time sorri see tuesday',
#  'wait know wesley town bet hella drug',
#  'fine miss much',
#  'u got person stori',
#  'tell drug dealer get impati',
#  'sun cant come earth send luv ray cloud cant come river send luv rain cant come meet u send care msg u gud evng',
#  'place man',
#  'doesnt make sen take unless free need know wikipediacom',
#  '88800 89034 premium phone servic call 08718711108',
#  'sea lay rock rock envelop envelop paper paper 3 word',
#  'mum repent',
#  'sorri go home first daddi come fetch ü later',
#  'leav de start prepar next',
#  'yes babi studi posit kama sutra',
#  'en chikku nang bakra msg kalstiyathen teacoff',
#  'carlosl minut still need buy',
#  'pay ltdecimalgt lakh',
#  'good even ttyl',
#  'u receiv msg',
#  'ho ho big belli laugh see ya tomo',
#  'sms ac sun0819 post helloyou seem cool want say hi hi stop send stop 62468',
#  'get ur 1st rington free repli msg tone gr8 top 20 tone phone everi week £150 per wk 2 opt send stop 08452810071 16',
#  'ditto wont worri say anyth anymor like said last night whatev want ill peac',
#  'ive got ltgt way could pick',
#  'dont knw pa drink milk',
#  'mayb say hi find got card great escap wetherspoon',
#  'piggi r u awak bet ure still sleep im go 4 lunch',
#  'caus im freaki lol',
#  'miss call caus yell scrappi miss u cant wait u come home im lone today',
#  'hex place talk explain',
#  'ü log 4 wat sdryb8i',
#  'xy go 4 e lunch',
#  'hi im sue 20 year old work lapdanc love sex text live im bedroom text sue 89555 textop g2 1da 150ppmsg 18',
#  'want ask ü wait 4 finish lect cos lect finish hour anyway',
#  'finish work yet',
#  'everi king cri babi everi great build map imprtant u r today u wil reach tomorw gud ni8',
#  'dearm cherthalain case u r come cochin pls call bfore u starti shall also reach accordinglyor tell day u r comingtmorow engag holiday',
#  'thank love torch bold',
#  'forward 448712404000plea call 08712404000 immedi urgent messag wait',
#  'farm open',
#  'sorri troubl u buy 4d dad 1405 1680 1843 2 big 1 small sat n sun thanx',
#  'sister law hope great month say hey abiola',
#  'purcha stuff today mail po box number',
#  'ah poop look like ill prob send laptop get fix cuz gpu problem',
#  'good good job like entrepreneur',
#  'aight close still around alex place',
#  'meet corpor st outsid gap … see mind work',
#  'mum ask ü buy food home',
#  'ku also dont msg repli msg',
#  'much r ü pay',
#  'sorri ill call later',
#  'import prevent dehydr give enough fluid',
#  'bit weird even suppo happen good idea sure pub',
#  'true deari sat pray even felt soso smsd time',
#  'dont think get away trek long famili town sorri',
#  'wan na gym harri',
#  'quit late lar ard 12 anyway wun b drivin',
#  'review keep fantast nokia ngage game deck club nokia go 2 wwwcnupdatescomnewslett unsubscrib alert repli word',
#  '4mths half price orang line rental latest camera phone 4 free phone 11mths call mobilesdirect free 08000938767 updat or2stoptxt tcs',
#  'height confid aeronaut professor wer calld amp wer askd 2 sit aeroplan aftr sat wer told dat plane ws made student dey hurri plane bt 1 didnt move saidif made studentsthi wont even start datz confid',
#  'seem like weird time night g want come smoke day shitstorm attribut alway come make everyon smoke',
#  '08714712388 10am7pm cost 10p',
#  'save stress person dorm account send account detail money sent',
#  'also know lunch menu da know',
#  'stuff sell ill tell',
#  '449071512431 urgent 2nd attempt contact uu £1250 call 09071512433 b4 050703 tcsbcm4235wc1n3xx callcost 150ppm mobilesvari max£7 50',
#  'book lesson msg call work sth im go get spec membership px3748',
#  'guarant £1000 cash £2000 prize claim yr prize call custom servic repr 08714712394 10am7pm',
#  'macha dont feel upseti assum mindsetbeliev one even wonder plan uslet life begin againc anytim',
#  'oh send address',
#  'sfine anytim best',
#  'wondar full flim',
#  'ya even cooki jelli',
#  'world run stillmayb feel sameso itor admiti madthen correctionor let call lifeand keep run worldmay u r also runninglet run',
#  'got look scrumptious daddi want eat night long',
#  'cos lar im ba dao ok 1 pm lor u never ask go ah said u would ask fri said u ask today',
#  'alright omw got ta chang order half8th',
#  'exact anyway far jide studi visit',
#  'dunno u ask',
#  'email alertfrom jeri stewart 2kbsubject lowcost prescripiton drvgsto listen email call 123',
#  'didnt spring come ear yay',
#  'lol wont feel bad use money take steak dinner',
#  'even u dont get troubl convincingjust tel twice tel neglect msgs dont c read itjust dont repli',
#  'leav qatar tonit search opportunity went fastpl add ur prayer dearrakhesh',
#  'one talk',
#  'thank look realli appreci',
#  'hi custom loyalti offerth new nokia6650 mobil £10 txtauction txt word start 81151 get 4tctxt tc 150pmtmsg',
#  'wish',
#  'haha mayb ure rite u know well da feel like someon gd lor u faster go find one gal group attach liao',
#  'yes glad made',
#  'well littl time thing good time ahead',
#  'got room soon … hadnt put clock back til 8 shout everyon get reali 7 wahay anoth hour bed',
#  'ok may free gym',
#  'men like shorter ladi gaze eye',
#  'dunno jus say go lido time 930',
#  'promi take good care princess run plea send pic get chanc ttyl',
#  'u subscrib best mobil content servic uk £3 per 10 day send stop 82324 helplin 08706091795',
#  'reason weve spoken year anyway great week best exam',
#  'monday next week give full gist',
#  'realiz 40 year well thousand old ladi run around tattoo',
#  'import custom servic announc premier',
#  'dont gim lip caveboy',
#  'get librari',
#  'reali sorryi dont recogni number confus r u plea',
#  'didnt holla',
#  'cant think anyon spare room top head',
#  'faith make thing possiblehop make thing worklov make thing beautifulmay three christmasmerri christma',
#  'u made appoint',
#  'call youcarlo isar phone vibrat act might hear text',
#  'romant pari 2 night 2 flight £79 book 4 next year call 08704439680tscs appli',
#  'grandma oh dear u still ill felt shit morn think hungov anoth night leav sat',
#  'urgent ur £500 guarant award still unclaim call 09066368327 closingdate040902 claimcod m39m51 £150pmmorefrommobile2bremovedmobypobox734ls27yf',
#  'noth jus tot u would ask cos u ba gua went mt faber yest yest jus went alreadi mah today go jus call lor',
#  'wish famili merri x mas happi new year advanc',
#  'ur award citi break could win £200 summer shop spree everi wk txt store 88039 skilgm tscs087147403231winawkage16 £150perwksub',
#  'im nt goin got somethin unless meetin 4 dinner lor haha wonder go tis time',
#  'sorri ill call later',
#  'cant pick phone right pls send messag',
#  'lol know theyr dramat school alreadi close tomorrow appar cant drive inch snow suppo get',
#  'get anywh damn job hunt',
#  'lol u drunkard hair moment yeah still 4 tonight wat plan',
#  'idc get weasel way shit twice row',
#  'wil ltgt minut got space',
#  'sleepingand surf',
#  'thank pick trash',
#  'dont go tell friend sure want live smoke much spend hour beg come smoke',
#  'hi kate love see tonight ill phone tomorrow got sing guy gave card xxx',
#  'happi new year dear brother realli miss got number decid send text wish happi abiola',
#  'mean get door',
#  'opinion 1 2 jada 3 kusruthi 4 lovabl 5 silent 6 spl charact 7 matur 8 stylish 9 simpl pls repli',
#  'hmmm thought said 2 hour slave 3 late punish',
#  'beerag',
#  'import custom servic announc premier call freephon 0800 542 0578',
#  'dont think turn like randomlli within 5min open',
#  'suppo couldnt make shes still town though',
#  'time fix spell sometim get complet diff word go figur',
#  'ever thought live good life perfect partner txt back name age join mobil communiti 100psms',
#  '5 free top polyphon tone call 087018728737 nation rate get toppoli tune sent everi week text subpoli 81618 £3 per pole unsub 08718727870',
#  'gud mrng dear hav nice day',
#  'hope enjoy game yesterday sorri ive touch pls know fond bein thot great week abiola',
#  'e best 4 ur drive tmr',
#  'ywhere u dogbreath sound like jan c that\x92 al',
#  'omg want scream weigh lost weight woohoo',
#  'general isnt one uncount noun u dictionari piec research',
#  'realli get hang around',
#  'orang custom may claim free camera phone upgrad loyalti call 0207 153 9996 offer end 14thmarch tcs appli optout availa',
#  'petey boy wherear friendsar thekingshead come canlov nic',
#  'ok msg u b4 leav hous',
#  'gim ltgt minut ago',
#  'last chanc claim ur £150 worth discount voucher today text shop 85023 savamob offer mobil cs savamob pobox84 m263uz £300 sub 16',
#  'appt lttimegt fault u dont listen told u twice',
#  'free 1st week no1 nokia tone 4 ur mobil everi week txt nokia 8077 get txting tell ur mate wwwgetzedcouk pobox 36504 w45wq 16 norm150pton',
#  'guarant £200 award even £1000 cashto claim ur award call free 08000407165 18 2 stop getstop 88222 php rg21 4jx',
#  'k ill 4',
#  'dled 3d imp',
#  'sure make sure know aint smokin yet',
#  'boooo alway work quit',
#  'take half day leav bec well',
#  'ugh dont wan na get bed warm',
#  'ssnervous ltgt',
#  'ring come guy costum gift futur yowif hint hint',
#  'congratul ur award either £500 cd gift voucher free entri 2 £100 week draw txt music 87066 tncs wwwldewcom1win150ppmx3age16',
#  'borrow ur bag ok',
#  'u outbid simonwatson5120 shinco dvd plyr 2 bid visit sms acsmsreward 2 end bid notif repli end',
#  'boytoy miss happen',
#  'lot use one babe model doesnt help youi bring hell match',
#  'also bring galileo dobbi',
#  'respond',
#  'boo babe u enjoyin yourjob u seem 2 b gettin well hunnyhop ure oktak care i\x92llspeak 2u soonlot lovem xxxx',
#  'good afternoon starshin boytoy crave yet ach fuck sip cappuccino miss babe tea kiss',
#  'road cant txt',
#  'smsservic yourinclus text credit pls goto wwwcomuknet login 3qxj9 unsubscrib stop extra charg help 08702840625comuk 220cm2 9ae',
#  '25p 4 alfi moon children need song ur mob tell ur m8s txt tone chariti 8007 nokia poli chariti poli zed 08701417012 profit 2 chariti',
#  'good even ttyl',
#  'hmm bit piec lol sigh',
#  'hahahaus brain dear',
#  'hey got mail',
#  'sorri light turn green meant anoth friend want ltgt worth may around',
#  'thank yesterday sir wonder hope enjoy burial mojibiola',
#  'u secret admir reveal think u r special call 09065174042 opt repli reveal stop 150 per msg recd cust care 07821230901',
#  'hi mate rv u hav nice hol messag 3 say hello coz haven\x92t sent u 1 age start drive stay roadsrvx',
#  'dear voucher holder claim week offer pc plea go httpwwwetlpcoukexpressoff tscs appli stop text txt stop 80062',
#  'thank much skype wit kz sura didnt get pleasur compani hope good weve given ultimatum oh countin aburo enjoy messag sent day ago',
#  'sure result offer',
#  'good morn dear great amp success day',
#  'want 750 anytim network min 150 text new video phone five pound per week call 08002888812 repli deliveri tomorrow',
#  'sir late pay rent past month pay ltgt charg felt would inconsid nag someth give great cost didnt speak howev recess wont abl pay charg month henc askin well ahead month end plea help thank',
#  'tri contact offer new video phone 750 anytim network min half price rental camcord call 08000930705 repli deliveri wed',
#  'last chanc 2 claim ur £150 worth discount voucherstext yes 85023 nowsavamobmemb offer mobil cs 08717898035 £300 sub 16 remov txt x stop',
#  'luv u soo much u don\x92t understand special u r 2 ring u 2morrow luv u xxx',
#  'pls send comprehen mail im pay much',
#  'prashanthettan mother pass away last night pray famili',
#  'urgent call 09066350750 landlin complimentari 4 ibiza holiday 10000 cash await collect sae tcs po box 434 sk3 8wp 150 ppm 18',
#  'kkwhen go',
#  'meanwhil shit suit xavier decid give us ltgt second warn samantha come play jay guitar impress shit also dont think doug realiz dont live anymor',
#  'stomach thru much trauma swear cant eat better lose weight',
#  'officewhat mattermsg nowi call break',
#  'yeah bare enough room two us x mani fuck shoe sorri man see later',
#  'today offer claim ur £150 worth discount voucher text yes 85023 savamob member offer mobil cs 08717898035 £300 sub 16 unsub repli x',
#  'u reach orchard alreadi u wan 2 go buy ticket first',
#  'real babi want bring inner tigress',
#  'da run activ full version da',
#  'ah poor babyhop urfeel bettersn luv probthat overdo work hey go care spk 2 u sn lot lovejen xxx',
#  'stop stori ive told ive return hes say order',
#  'talk sexi make new friend fall love world discreet text date servic text vip 83110 see could meet',
#  'go take babe',
#  'hai ana tomarrow come morn ltdecimalgt ill sathi go rto offic repli came home',
#  'spoon okay',
#  'say somebodi name tampa',
#  'work go min',
#  'brother genius',
#  'sorri guess whenev get hold connect mayb hour two ill text',
#  'u find time bus coz need sort stuff',
#  'dude ive see lotta corvett late',
#  'congratul ur award either yrs suppli cds virgin record mysteri gift guarant call 09061104283 tscs wwwsmsconet £150pm approx 3min',
#  'consid wall bunker shit import never play peac guess place high enough dont matter',
#  'privat 2003 account statement 07808 xxxxxx show 800 unredeem point call 08719899217 identifi code 41685 expir 071104',
#  'hello need posh bird chap user trial prod champney put need address dob asap ta r',
#  'u want xmas 100 free text messag new video phone half price line rental call free 0800 0721072 find',
#  'well offici philosoph hole u wan na call home readi save',
#  'go goodno problembut still need littl experi understand american custom voic',
#  'ill text drop x',
#  'ugh long day im exhaust want cuddl take nap',
#  'talk atleast day otherwi miss best friend world shakespear shesil ltgt',
#  'shop till u drop either 10k 5k £500 cash £100 travel voucher call 09064011000 ntt po box cr01327bt fixedlin cost 150ppm mobil vari',
#  'castor need see someth',
#  'sunshin quiz wkli q win top soni dvd player u know countri liverpool play mid week txt ansr 82277 £150 sptyron',
#  'u secret admir look 2 make contact ufind rreveal think ur specialc 09058094565',
#  'u secret admir look 2 make contact ufind rreveal think ur specialc 09065171142stopsms08',
#  'remind download content alreadi paid goto httpdoit mymobi tv collect content',
#  'see knew give break time woul lead alway want miss curfew gon na gibe til one midnight movi gon na get til 2 need come home need getsleep anyth need b studdi ear train',
#  'love give massag use lot babi oil fave posit',
#  'dude go sup',
#  'yoyyooo u know chang permiss drive mac usb flash drive',
#  'gibb unsoldmik hussey',
#  'like talk pa abl dont know',
#  'dun cut short leh u dun like ah fail shes quit sad',
#  'unbeliev faglord',
#  'wifehow knew time murder exact',
#  'ask princess',
#  'great princess think',
#  'nutter cutter ctter cttergg cttargg ctargg ctagg ie',
#  'ok noe ure busi im realli bore msg u oso dunno wat colour choo 4 one',
#  'doesnt g class ear tomorrow thus shouldnt tri smoke ltgt',
#  'superb thought grate u dont everyth u want mean u still opportun happier tomorrow u today',
#  'hope good week check',
#  'im use hope agent dont drop sinc ive book thing year whole boston nyc experi',
#  'thursday night yeah sure thing well work',
#  'free rington wait collect simpli text password mix 85069 verifi get usher britney fml po box 5249 mk17 92h 450ppw 16',
#  'probabl money worri thing come due sever outstand invoic work two three month ago',
#  'possibl teach',
#  'wonder phone batteri went dead tell love babe',
#  'love smell bus aint tobacco',
#  'get worri derek taylor alreadi assum worst',
#  'hey charl sorri late repli',
#  'lastest stereophon marley dizz racal libertin stroke win nookii game flirt click themob wap bookmark text wap 82468',
#  'ill give plus said grinul greet whenev speak',
#  'white fudg oreo store',
#  'januari male sale hot gay chat cheaper call 08709222922 nation rate 15pmin cheap 78pmin peak stop text call 08712460324 10pmin',
#  'love come took long leav zaher got word ym happi see sad left miss',
#  'sorri hurt',
#  'cant feel nauseous im piss didnt eat sweet week caus today plan pig diet week im hungri',
#  'ok lor ear still project meet',
#  'call da wait call',
#  'could ask carlo could get anybodi el chip',
#  'actual send remind today wonder weekend',
#  'peopl see msgs think iam addict msging wrong bcoz dont know iam addict sweet friend bslvyl',
#  'hey gave photo regist drive ah tmr wan na meet yck',
#  'dont talk ever ok word',
#  'u wana see',
#  'way school pls send ashley number',
#  'shall fine avalarr hollalat',
#  'went attend anoth two round todaybut still didt reach home',
#  'actual delet old websitenow blog magicalsongsblogspotcom',
#  'k wait chikkuil send aftr ltgt min',
#  'im diet ate 1 mani slice pizza yesterday ugh im alway diet',
#  'ki give kvb acc detail',
#  'oh come ah',
#  'money r lucki winner 2 claim prize text money 2 88600 £1million give away ppt150x3normal text rate box403 w1t1ji',
#  'im realli sorri wont b abl 2 fridayhop u find alternativehop yr term go ok',
#  'congratul ore mo owo wa enjoy wish mani happi moment fro wherev go',
#  'samus shoulder yet',
#  'time think youll need know near campus',
#  'dear matthew plea call 09063440451 landlin complimentari 4lux tenerif holiday £1000 cash await collect ppm150 sae tcs box334 sk38xh',
#  'dun wear jean lor',
#  'sinc side fever vomitin',
#  'kkare colleg',
#  'urgent call 09061749602 landlin complimentari 4 tenerif holiday £10000 cash await collect sae tcs box 528 hp20 1yf 150ppm 18',
#  'better made friday stuf like pig yesterday feel bleh least writh pain kind bleh',
#  'sell well ton coin sell coin someon thru paypal voila money back life pocket',
#  'theyr lot place hospit medic place safe',
#  'get touch folk wait compani txt back name age opt enjoy communiti 150psms',
#  'also ive sorta blown coupl time recent id rather text blue look weed',
#  'sent score sopha secondari applic school think think appli research cost also contact joke ogunrind school one less expen one',
#  'cant wait see photo use',
#  'ur cashbal current 500 pound maxim ur cashin send go 86688 150pmsg cc 08718720201 po box 11414 tcrw1',
#  'hey book kb sat alreadi lesson go ah keep sat night free need meet confirm lodg',
#  'chk ur belovd ms dict',
#  'time want come',
#  'awesom lem know whenev around',
#  'shb b ok lor thanx',
#  'beauti truth graviti read care heart feel light someon feel heavi someon leav good night',
#  'also rememb get dobbi bowl car',
#  'filthi stori girl wait',
#  'sorri c ur msg yar lor poor thing 4 one night tmr ull brand new room 2 sleep',
#  'love isnt deci feel could decid love life would much simpler less magic',
#  'welp appar retir',
#  'sort code acc bank natwest repli confirm ive sent right person',
#  '',
#  'u sure u cant take sick time',
#  'urgent tri contact u today draw show £800 prize guarant call 09050001808 land line claim m95 valid12hr',
#  'watch cartoon listen music amp eve go templ amp church u',
#  'yo chad gymnast class wan na take site say christian class full',
#  'much buzi',
#  'better still catch let ask sell ltgt',
#  'sure night menu know noon menu',
#  'u want come backa beauti necklac token heart youthat give wife likingb seeno one give thatdont call mei wait till come',
#  'go aptitud class',
#  'wont b 215 tri 2 sort hous ok',
#  'yar lor wan 2 go c hor race today mah eat earlier lor ate chicken rice u',
#  'haha awesom omw back',
#  'yup thk e shop close lor',
#  'account number',
#  'eh u send wrong lar',
#  'hey ad crap nite borin without ya 2 boggi u bore biatch thanx u wait til nxt time il ave ya',
#  'ok shall talk',
#  'dont hesit know second time weak like keep notebook eat day anyth chang day sure noth',
#  'hey pay salari de ltgt',
#  'anoth month need chocol weed alcohol',
#  'start search get job daysh great potenti talent',
#  'reckon need town eightish walk carpark',
#  'congrat 2 mobil 3g videophon r call 09063458130 videochat wid mate play java game dload polyph music nolin rentl',
#  'look fuckin time fuck think',
#  'yo guess drop',
#  'carlo say hell mu ltgt minut',
#  'im offic call ltgt min',
#  'geeee miss alreadi know think fuck cant wait till next year togeth love kiss',
#  'yun ahth ubi one say ü wan call tomorrowc 67441233 look iren got bus822656166382 ubi cresubi tech park6ph 1st 5wkg daysèn',
#  'ugh got ta drive back sd la butt sore',
#  '26th juli',
#  'hi im relax time ever get 7am everi day parti good night get home tomorrow 5ish',
#  'ü ü wan come come lor din c stripe skirt',
#  'xmas stori peac xmas msg love xmas miracl jesus hav bless month ahead amp wish u merri xmas',
#  'cant dont number',
#  'chang e one next escal',
#  'yetund im class run water make ok pls',
#  'lot happen feel quiet beth aunt char work lot helen mo',
#  'ü wait 4 bus stop aft ur lect lar dun c ü go get car come back n pick ü',
#  ...]

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features=2500)
X = cv.fit_transform(corpus).toarray()

# %%
y=pd.get_dummies(dataset['label'])
y
# Out:
#         ham   spam
# 0      True  False
# 1      True  False
# 2     False   True
# 3      True  False
# 4      True  False
# ...     ...    ...
# 5567  False   True
# 5568   True  False
# 5569   True  False
# 5570   True  False
# 5571   True  False
#
# [5572 rows x 2 columns]

# %%
#Getting Spam values
y=y.iloc[:,1].values
y
# Out:
# array([False, False,  True, ..., False, False, False])

# %% [markdown]
# # BOW Model Implementation

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 0)

# %%
from sklearn.naive_bayes import MultinomialNB
spam_detect_model = MultinomialNB().fit(X_train, y_train)

# %%
#prediction
y_pred=spam_detect_model.predict(X_test)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.99      0.99      0.99       953
#         True       0.95      0.94      0.94       162
#
#     accuracy                           0.98      1115
#    macro avg       0.97      0.96      0.97      1115
# weighted avg       0.98      0.98      0.98      1115

# %% [markdown]
# # TF-IDF Model implementation

# %%
# Creating the TFIDF model
from sklearn.feature_extraction.text import TfidfVectorizer
tv = TfidfVectorizer(max_features=2500)
X = tv.fit_transform(corpus).toarray()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 0)

# %%
spam_detect_model_tf_idf = MultinomialNB().fit(X_train, y_train)

# %%
#TF-IDF prediction
y_pred_tf_idf = spam_detect_model_tf_idf.predict(X_test)

# %%
print(classification_report(y_pred_tf_idf,y_test))
# Out:
#               precision    recall  f1-score   support
#
#        False       1.00      0.98      0.99       973
#         True       0.88      0.99      0.93       142
#
#     accuracy                           0.98      1115
#    macro avg       0.94      0.99      0.96      1115
# weighted avg       0.98      0.98      0.98      1115

# %% [markdown]
# # Word2vec Implementation

# %%
# !pip install gensim
# Out:
# Requirement already satisfied: gensim in c:\aplica\nlp-project-spam-classifier-word2vec\.venv\lib\site-packages (4.3.3)
# Requirement already satisfied: numpy<2.0,>=1.18.5 in c:\aplica\nlp-project-spam-classifier-word2vec\.venv\lib\site-packages (from gensim) (1.26.4)
# Requirement already satisfied: scipy<1.14.0,>=1.7.0 in c:\aplica\nlp-project-spam-classifier-word2vec\.venv\lib\site-packages (from gensim) (1.13.1)
# Requirement already satisfied: smart-open>=1.8.1 in c:\aplica\nlp-project-spam-classifier-word2vec\.venv\lib\site-packages (from gensim) (7.0.4)
# Requirement already satisfied: wrapt in c:\aplica\nlp-project-spam-classifier-word2vec\.venv\lib\site-packages (from smart-open>=1.8.1->gensim) (1.16.0)

# %%
import gensim

# %%
from gensim.models import Word2Vec, KeyedVectors

# %%
import gensim.downloader as api

wv = api.load('word2vec-google-news-300')

# %%
messages = dataset['message']

# %%
from nltk.stem import WordNetLemmatizer
lemmatizer=WordNetLemmatizer()

# %%
corpus_w2v = []
for i in range(len(messages)):
    messages[i] = messages[i].lower().translate(str.maketrans('', '', string.punctuation))
    words = nltk.word_tokenize(messages[i])
    words = [lemmatizer.lemmatize(word) for word in words if word not in stop_words_EN]
    messages[i] = ' '.join(words)
    corpus_w2v.append(messages[i])

# %%
corpus_w2v[100]
# Out:
# 'plea dont text anymor noth el say'

# %%
from gensim.utils import simple_preprocess
from nltk import sent_tokenize

# %%
help(simple_preprocess)
# Out:
# Help on function simple_preprocess in module gensim.utils:
#
# simple_preprocess(doc, deacc=False, min_len=2, max_len=15)
#     Convert a document into a list of lowercase tokens, ignoring tokens that are too short or too long.
#
#     Uses :func:`~gensim.utils.tokenize` internally.
#
#     Parameters
#     ----------
#     doc : str
#         Input document.
#     deacc : bool, optional
#         Remove accent marks from tokens using :func:`~gensim.utils.deaccent`?
#     min_len : int, optional
#         Minimum length of token (inclusive). Shorter tokens are discarded.
#     max_len : int, optional
#         Maximum length of token in result (inclusive). Longer tokens are discarded.
#
#     Returns
#     -------
#     list of str
#         Tokens extracted from `doc`.

# %%
sentences=[]
for sent in corpus_w2v:
    sent_token=sent_tokenize(sent)
    for sent in sent_token:
        sentences.append(simple_preprocess(sent))

# %%
sentences
# Out:
# [['go',
#   'jurong',
#   'point',
#   'crazi',
#   'avail',
#   'bugi',
#   'great',
#   'world',
#   'la',
#   'buffet',
#   'cine',
#   'got',
#   'amor',
#   'wat'],
#  ['ok', 'lar', 'joke', 'wif', 'oni'],
#  ['free',
#   'entri',
#   'wkli',
#   'comp',
#   'win',
#   'fa',
#   'cup',
#   'final',
#   'tkts',
#   'st',
#   'may',
#   'text',
#   'fa',
#   'receiv',
#   'entri',
#   'questionstd',
#   'txt',
#   'ratetc',
#   'appli',
#   'over'],
#  ['dun', 'say', 'earli', 'hor', 'alreadi', 'say'],
#  ['nah', 'dont', 'think', 'goe', 'usf', 'live', 'around', 'though'],
#  ['freemsg',
#   'hey',
#   'darl',
#   'week',
#   'word',
#   'back',
#   'id',
#   'like',
#   'fun',
#   'still',
#   'tb',
#   'ok',
#   'xxx',
#   'std',
#   'chgs',
#   'send',
#   'rcv'],
#  ['even', 'brother', 'like', 'speak', 'treat', 'like', 'aid', 'patent'],
#  ['per',
#   'request',
#   'mell',
#   'mell',
#   'oru',
#   'minnaminungint',
#   'nurungu',
#   'vettam',
#   'set',
#   'callertun',
#   'caller',
#   'press',
#   'copi',
#   'friend',
#   'callertun'],
#  ['winner',
#   'valu',
#   'network',
#   'custom',
#   'select',
#   'receivea',
#   'prize',
#   'reward',
#   'claim',
#   'call',
#   'claim',
#   'code',
#   'kl',
#   'valid',
#   'hour'],
#  ['mobil',
#   'month',
#   'entitl',
#   'updat',
#   'latest',
#   'colour',
#   'mobil',
#   'camera',
#   'free',
#   'call',
#   'mobil',
#   'updat',
#   'co',
#   'free'],
#  ['im',
#   'gon',
#   'na',
#   'home',
#   'soon',
#   'dont',
#   'want',
#   'talk',
#   'stuff',
#   'anymor',
#   'tonight',
#   'ive',
#   'cri',
#   'enough',
#   'today'],
#  ['six',
#   'chanc',
#   'win',
#   'cash',
#   'pound',
#   'txt',
#   'csh',
#   'send',
#   'cost',
#   'pday',
#   'day',
#   'tsandc',
#   'appli',
#   'repli',
#   'hl',
#   'info'],
#  ['urgent',
#   'week',
#   'free',
#   'membership',
#   'prize',
#   'jackpot',
#   'txt',
#   'word',
#   'claim',
#   'tc',
#   'wwwdbuknet',
#   'lccltd',
#   'pobox',
#   'ldnw',
#   'rw'],
#  ['ive',
#   'search',
#   'right',
#   'word',
#   'thank',
#   'breather',
#   'promis',
#   'wont',
#   'take',
#   'help',
#   'grant',
#   'fulfil',
#   'promis',
#   'wonder',
#   'bless',
#   'time'],
#  ['date', 'sunday'],
#  ['use',
#   'credit',
#   'click',
#   'wap',
#   'link',
#   'next',
#   'txt',
#   'messag',
#   'click',
#   'httpwap'],
#  ['oh', 'kim', 'watch'],
#  ['eh', 'rememb', 'spell', 'name', 'yes', 'naughti', 'make', 'wet'],
#  ['fine', 'that', 'way', 'feel', 'that', 'way', 'gota'],
#  ['england',
#   'macedonia',
#   'dont',
#   'miss',
#   'goalsteam',
#   'news',
#   'txt',
#   'ur',
#   'nation',
#   'team',
#   'eg',
#   'england',
#   'trywal',
#   'scotland',
#   'txtú',
#   'poboxox',
#   'wq'],
#  ['serious', 'spell', 'name'],
#  ['go', 'tri', 'month', 'ha', 'ha', 'joke'],
#  ['pay', 'first', 'lar', 'da', 'stock', 'comin'],
#  ['aft',
#   'finish',
#   'lunch',
#   'go',
#   'str',
#   'lor',
#   'ard',
#   'smth',
#   'lor',
#   'finish',
#   'ur',
#   'lunch',
#   'alreadi'],
#  ['ffffffffff', 'alright', 'way', 'meet', 'sooner'],
#  ['forc',
#   'eat',
#   'slice',
#   'im',
#   'realli',
#   'hungri',
#   'tho',
#   'suck',
#   'mark',
#   'get',
#   'worri',
#   'know',
#   'im',
#   'sick',
#   'turn',
#   'pizza',
#   'lol'],
#  ['lol', 'alway', 'convinc'],
#  ['catch',
#   'bus',
#   'fri',
#   'egg',
#   'make',
#   'tea',
#   'eat',
#   'mom',
#   'left',
#   'dinner',
#   'feel',
#   'love'],
#  ['im', 'back', 'amp', 'pack', 'car', 'ill', 'let', 'know', 'room'],
#  ['ahhh', 'work', 'vagu', 'rememb', 'feel', 'like', 'lol'],
#  ['wait', 'still', 'clear', 'sure', 'sarcast', 'doesnt', 'want', 'live'],
#  ['yeah',
#   'got',
#   'apologet',
#   'fallen',
#   'actin',
#   'like',
#   'spoilt',
#   'child',
#   'got',
#   'caught',
#   'till',
#   'wont',
#   'go',
#   'bad',
#   'cheer'],
#  ['tell', 'anyth'],
#  ['fear', 'faint', 'housework', 'quick', 'cuppa'],
#  ['thank',
#   'subscript',
#   'rington',
#   'uk',
#   'mobil',
#   'charg',
#   'month',
#   'plea',
#   'confirm',
#   'repli',
#   'yes',
#   'repli',
#   'charg'],
#  ['yup',
#   'ok',
#   'go',
#   'home',
#   'look',
#   'time',
#   'msg',
#   'xuhui',
#   'go',
#   'learn',
#   'nd',
#   'may',
#   'lesson',
#   'am'],
#  ['oop', 'ill', 'let', 'know', 'roommat', 'done'],
#  ['see', 'letter', 'car'],
#  ['anyth', 'lor', 'decid'],
#  ['hello',
#   'saturday',
#   'go',
#   'text',
#   'see',
#   'youd',
#   'decid',
#   'anyth',
#   'tomo',
#   'im',
#   'tri',
#   'invit',
#   'anyth'],
#  ['pls', 'go', 'ahead', 'watt', 'want', 'sure', 'great', 'weekend', 'abiola'],
#  ['forget',
#   'tell',
#   'want',
#   'need',
#   'crave',
#   'love',
#   'sweet',
#   'arabian',
#   'steed',
#   'mmmmmm',
#   'yummi'],
#  ['rodger',
#   'burn',
#   'msg',
#   'tri',
#   'call',
#   'repli',
#   'sm',
#   'free',
#   'nokia',
#   'mobil',
#   'free',
#   'camcord',
#   'plea',
#   'call',
#   'deliveri',
#   'tomorrow'],
#  ['see'],
#  ['great', 'hope', 'like', 'man', 'well', 'endow', 'ltgt', 'inch'],
#  ['call'],
#  ['didnt', 'get', 'hep', 'immunis', 'nigeria'],
#  ['fair', 'enough', 'anyth', 'go'],
#  ['yeah', 'hope', 'tyler', 'cant', 'could', 'mayb', 'ask', 'around', 'bit'],
#  ['dont',
#   'know',
#   'stubborn',
#   'didnt',
#   'even',
#   'want',
#   'go',
#   'hospit',
#   'kept',
#   'tell',
#   'mark',
#   'im',
#   'weak',
#   'sucker',
#   'hospit',
#   'weak',
#   'sucker'],
#  ['think', 'first', 'time', 'saw', 'class'],
#  ['gram',
#   'usual',
#   'run',
#   'like',
#   'ltgt',
#   'half',
#   'eighth',
#   'smarter',
#   'though',
#   'get',
#   'almost',
#   'whole',
#   'second',
#   'gram',
#   'ltgt'],
#  ['fyi',
#   'ride',
#   'earli',
#   'tomorrow',
#   'morn',
#   'he',
#   'crash',
#   'place',
#   'tonight'],
#  ['wow',
#   'never',
#   'realiz',
#   'embarass',
#   'accomod',
#   'thought',
#   'like',
#   'sinc',
#   'best',
#   'could',
#   'alway',
#   'seem',
#   'happi',
#   'cave',
#   'im',
#   'sorri',
#   'didnt',
#   'dont',
#   'give',
#   'im',
#   'sorri',
#   'offer',
#   'im',
#   'sorri',
#   'room',
#   'embarass'],
#  ['sm',
#   'ac',
#   'sptv',
#   'new',
#   'jersey',
#   'devil',
#   'detroit',
#   'red',
#   'wing',
#   'play',
#   'ice',
#   'hockey',
#   'correct',
#   'incorrect',
#   'end',
#   'repli',
#   'end',
#   'sptv'],
#  ['know', 'mallika', 'sherawat', 'yesterday', 'find', 'lturlgt'],
#  ['congrat',
#   'year',
#   'special',
#   'cinema',
#   'pas',
#   'call',
#   'suprman',
#   'matrix',
#   'starwars',
#   'etc',
#   'free',
#   'bx',
#   'ip',
#   'pm',
#   'dont',
#   'miss'],
#  ['sorri', 'ill', 'call', 'later', 'meet'],
#  ['tell', 'reach'],
#  ['yesgauti', 'sehwag', 'odi', 'seri'],
#  ['gon',
#   'na',
#   'pick',
#   'burger',
#   'way',
#   'home',
#   'cant',
#   'even',
#   'move',
#   'pain',
#   'kill'],
#  ['ha', 'ha', 'ha', 'good', 'joke', 'girl', 'situat', 'seeker'],
#  ['part', 'check', 'iq'],
#  ['sorri', 'roommat', 'took', 'forev', 'ok', 'come'],
#  ['ok',
#   'lar',
#   'doubl',
#   'check',
#   'wif',
#   'da',
#   'hair',
#   'dresser',
#   'alreadi',
#   'said',
#   'wun',
#   'cut',
#   'short',
#   'said',
#   'cut',
#   'look',
#   'nice'],
#  ['valu',
#   'custom',
#   'plea',
#   'advis',
#   'follow',
#   'recent',
#   'review',
#   'mob',
#   'award',
#   'bonus',
#   'prize',
#   'call'],
#  ['today',
#   'song',
#   'dedic',
#   'day',
#   'song',
#   'dedic',
#   'send',
#   'ur',
#   'valuabl',
#   'frnds',
#   'first',
#   'rpli'],
#  ['urgent',
#   'ur',
#   'award',
#   'complimentari',
#   'trip',
#   'eurodisinc',
#   'trav',
#   'acoentry',
#   'claim',
#   'txt',
#   'dis',
#   'morefrmmob',
#   'ls',
#   'aj'],
#  ['hear', 'new', 'divorc', 'barbi', 'come', 'ken', 'stuff'],
#  ['plane', 'give', 'month', 'end'],
#  ['wah', 'lucki', 'man', 'save', 'money', 'hee'],
#  ['finish', 'class'],
#  ['hi', 'babe', 'im', 'home', 'wan', 'na', 'someth', 'xx'],
#  ['kkwhere', 'youhow', 'perform'],
#  ['call'],
#  ['wait', 'machan', 'call', 'free'],
#  ['cool', 'gentleman', 'treat', 'digniti', 'respect'],
#  ['like', 'peopl', 'much', 'shi', 'pa'],
#  ['oper', 'ltgt'],
#  ['still', 'look', 'job', 'much', 'ta', 'earn'],
#  ['sorri', 'ill', 'call', 'later'],
#  ['call', 'ah'],
#  ['ok', 'way', 'home', 'hi', 'hi'],
#  ['place', 'man'],
#  ['yup', 'next', 'stop'],
#  ['call', 'later', 'dont', 'network', 'urgnt', 'sm'],
#  ['real',
#   'get',
#   'yo',
#   'need',
#   'ticket',
#   'one',
#   'jacket',
#   'im',
#   'done',
#   'alreadi',
#   'use',
#   'multi'],
#  ['yes',
#   'start',
#   'send',
#   'request',
#   'make',
#   'pain',
#   'came',
#   'back',
#   'im',
#   'back',
#   'bed',
#   'doubl',
#   'coin',
#   'factori',
#   'got',
#   'ta',
#   'cash',
#   'nitro'],
#  ['im', 'realli', 'still', 'tonight', 'babe'],
#  ['ela', 'kanoil', 'download', 'come', 'wen', 'ur', 'free'],
#  ['yeah', 'stand', 'close', 'tho', 'catch', 'someth'],
#  ['sorri',
#   'pain',
#   'ok',
#   'meet',
#   'anoth',
#   'night',
#   'spent',
#   'late',
#   'afternoon',
#   'casualti',
#   'mean',
#   'havent',
#   'done',
#   'stuff',
#   'moro',
#   'includ',
#   'time',
#   'sheet',
#   'sorri'],
#  ['smile',
#   'pleasur',
#   'smile',
#   'pain',
#   'smile',
#   'troubl',
#   'pour',
#   'like',
#   'rain',
#   'smile',
#   'sum',
#   'hurt',
#   'smile',
#   'becoz',
#   'someon',
#   'still',
#   'love',
#   'see',
#   'smile'],
#  ['plea',
#   'call',
#   'custom',
#   'servic',
#   'repres',
#   'am',
#   'pm',
#   'guarante',
#   'cash',
#   'prize'],
#  ['havent',
#   'plan',
#   'buy',
#   'later',
#   'check',
#   'alreadi',
#   'lido',
#   'got',
#   'show',
#   'afternoon',
#   'finish',
#   'work',
#   'alreadi'],
#  ['free',
#   'rington',
#   'wait',
#   'collect',
#   'simpli',
#   'text',
#   'password',
#   'mix',
#   'verifi',
#   'get',
#   'usher',
#   'britney',
#   'fml',
#   'po',
#   'box',
#   'mk',
#   'ppw'],
#  ['watch', 'telugu', 'moviewat', 'abt'],
#  ['see', 'finish', 'load', 'loan', 'pay'],
#  ['hi',
#   'wk',
#   'ok',
#   'hol',
#   'yes',
#   'bit',
#   'run',
#   'forgot',
#   'hairdress',
#   'appoint',
#   'four',
#   'need',
#   'get',
#   'home',
#   'shower',
#   'beforehand',
#   'caus',
#   'prob'],
#  ['see', 'cup', 'coffe', 'anim'],
#  ['plea', 'dont', 'text', 'anymor', 'noth', 'el', 'say'],
#  ['okay', 'name', 'ur', 'price', 'long', 'legal', 'wen', 'pick', 'ave', 'xx'],
#  ['im', 'still', 'look', 'car', 'buy', 'gone', 'the', 'drive', 'test', 'yet'],
#  ['per',
#   'request',
#   'mell',
#   'mell',
#   'oru',
#   'minnaminungint',
#   'nurungu',
#   'vettam',
#   'set',
#   'callertun',
#   'caller',
#   'press',
#   'copi',
#   'friend',
#   'callertun'],
#  ['wow',
#   'right',
#   'didnt',
#   'mean',
#   'guess',
#   'gave',
#   'boston',
#   'men',
#   'chang',
#   'search',
#   'locat',
#   'nyc',
#   'someth',
#   'chang',
#   'cuz',
#   'signin',
#   'page',
#   'still',
#   'say',
#   'boston'],
#  ['umma', 'life', 'vava', 'umma', 'love', 'lot', 'dear'],
#  ['thank',
#   'lot',
#   'wish',
#   'birthday',
#   'thank',
#   'make',
#   'birthday',
#   'truli',
#   'memor'],
#  ['aight', 'ill', 'hit', 'get', 'cash'],
#  ['would',
#   'ip',
#   'address',
#   'test',
#   'consid',
#   'comput',
#   'isnt',
#   'minecraft',
#   'server'],
#  ['know',
#   'grumpi',
#   'old',
#   'peopl',
#   'mom',
#   'like',
#   'better',
#   'lie',
#   'alway',
#   'one',
#   'play',
#   'joke'],
#  ['dont', 'worri', 'guess', 'he', 'busi'],
#  ['plural', 'noun', 'research'],
#  ['go', 'dinnermsg'],
#  ['im',
#   'ok',
#   'wif',
#   'co',
#   'like',
#   'tri',
#   'new',
#   'thing',
#   'scare',
#   'dun',
#   'like',
#   'mah',
#   'co',
#   'said',
#   'loud'],
#  ['gent',
#   'tri',
#   'contact',
#   'last',
#   'weekend',
#   'draw',
#   'show',
#   'prize',
#   'guarante',
#   'call',
#   'claim',
#   'code',
#   'valid',
#   'hrs',
#   'ppm'],
#  ['wa',
#   'ur',
#   'openin',
#   'sentenc',
#   'formal',
#   'anyway',
#   'im',
#   'fine',
#   'juz',
#   'tt',
#   'im',
#   'eatin',
#   'much',
#   'puttin',
#   'weighthaha',
#   'anythin',
#   'special',
#   'happen'],
#  ['enter',
#   'cabin',
#   'pa',
#   'said',
#   'happi',
#   'bday',
#   'bos',
#   'felt',
#   'special',
#   'askd',
#   'lunch',
#   'lunch',
#   'invit',
#   'apart',
#   'went'],
#  ['winner',
#   'special',
#   'select',
#   'receiv',
#   'holiday',
#   'flight',
#   'inc',
#   'speak',
#   'live',
#   'oper',
#   'claim',
#   'pmin'],
#  ['goodo',
#   'yes',
#   'must',
#   'speak',
#   'friday',
#   'eggpotato',
#   'ratio',
#   'tortilla',
#   'need'],
#  ['hmmmi',
#   'uncl',
#   'inform',
#   'he',
#   'pay',
#   'school',
#   'direct',
#   'pls',
#   'buy',
#   'food'],
#  ['privat',
#   'account',
#   'statement',
#   'show',
#   'unredeem',
#   'bonus',
#   'point',
#   'claim',
#   'call',
#   'identifi',
#   'code',
#   'expir'],
#  ['urgent',
#   'mobil',
#   'award',
#   'bonus',
#   'caller',
#   'prize',
#   'final',
#   'tri',
#   'contact',
#   'call',
#   'landlin',
#   'box',
#   'wr',
#   'ppm'],
#  ['new', 'address', 'applespairsal', 'malarki'],
#  ['today',
#   'voda',
#   'number',
#   'end',
#   'select',
#   'receiv',
#   'award',
#   'match',
#   'plea',
#   'call',
#   'quot',
#   'claim',
#   'code',
#   'standard',
#   'rate',
#   'app'],
#  ['go', 'sao', 'mu', 'today', 'done'],
#  ['predict', 'wat', 'time', 'üll', 'finish', 'buy'],
#  ['good', 'stuff'],
#  ['knowyetund',
#   'hasnt',
#   'sent',
#   'money',
#   'yet',
#   'sent',
#   'text',
#   'bother',
#   'send',
#   'dont',
#   'involv',
#   'anyth',
#   'shouldnt',
#   'impos',
#   'anyth',
#   'first',
#   'place',
#   'apologis'],
#  ['room'],
#  ['hey',
#   'girl',
#   'hope',
#   'well',
#   'del',
#   'bak',
#   'long',
#   'time',
#   'give',
#   'call',
#   'sum',
#   'time',
#   'lucyxx'],
#  ['kkhow', 'much', 'cost'],
#  ['im', 'home'],
#  ['dear', 'call', 'tmorrowpl', 'accomod'],
#  ['first', 'answer', 'question'],
#  ['sunshin',
#   'quiz',
#   'wkli',
#   'win',
#   'top',
#   'soni',
#   'dvd',
#   'player',
#   'know',
#   'countri',
#   'algarv',
#   'txt',
#   'ansr',
#   'sptyron'],
#  ['want',
#   'get',
#   'laid',
#   'tonight',
#   'want',
#   'real',
#   'dog',
#   'locat',
#   'sent',
#   'direct',
#   'ur',
#   'mob',
#   'join',
#   'uk',
#   'largest',
#   'dog',
#   'network',
#   'bt',
#   'txting',
#   'gravel',
#   'nt',
#   'ec',
#   'pmsg'],
#  ['haf', 'msn', 'yijuehotmailcom'],
#  ['call', 'meet'],
#  ['check', 'room', 'befor', 'activ'],
#  ['youll',
#   'rcv',
#   'msg',
#   'chat',
#   'svc',
#   'free',
#   'hardcor',
#   'servic',
#   'text',
#   'go',
#   'get',
#   'noth',
#   'must',
#   'age',
#   'verifi',
#   'yr',
#   'network',
#   'tri'],
#  ['got', 'lazi', 'type', 'forgot', 'lect', 'saw', 'pouch', 'like', 'nice'],
#  ['text', 'way'],
#  ['sir', 'wait', 'mail'],
#  ['swt',
#   'thought',
#   'nver',
#   'get',
#   'tire',
#   'littl',
#   'thing',
#   'lovabl',
#   'person',
#   'cozsomtim',
#   'littl',
#   'thing',
#   'occupi',
#   'biggest',
#   'part',
#   'heart',
#   'gud',
#   'ni'],
#  ['know', 'pls', 'open', 'back'],
#  ['yes', 'see', 'ya', 'dot'],
#  ['staff', 'name', 'take', 'class'],
#  ['freemsg',
#   'havent',
#   'repli',
#   'text',
#   'im',
#   'randi',
#   'sexi',
#   'femal',
#   'live',
#   'local',
#   'luv',
#   'hear',
#   'netcollex',
#   'ltd',
#   'per',
#   'msg',
#   'repli',
#   'stop',
#   'end'],
#  ['ummmawil',
#   'call',
#   'check',
#   'inour',
#   'life',
#   'begin',
#   'qatar',
#   'pls',
#   'pray',
#   'hard'],
#  ['ki', 'delet', 'contact'],
#  ['sindu', 'got', 'job', 'birla', 'soft'],
#  ['wine', 'flow', 'im', 'never'],
#  ['yup', 'thk', 'cine', 'better', 'co', 'need', 'go', 'plaza', 'mah'],
#  ['ok', 'ur', 'typic', 'repli'],
#  ['per',
#   'request',
#   'mell',
#   'mell',
#   'oru',
#   'minnaminungint',
#   'nurungu',
#   'vettam',
#   'set',
#   'callertun',
#   'caller',
#   'press',
#   'copi',
#   'friend',
#   'callertun'],
#  ['everywher',
#   'dirt',
#   'floor',
#   'window',
#   'even',
#   'shirt',
#   'sometim',
#   'open',
#   'mouth',
#   'come',
#   'flow',
#   'dream',
#   'world',
#   'without',
#   'half',
#   'chore',
#   'time',
#   'joy',
#   'lot',
#   'tv',
#   'show',
#   'ill',
#   'see',
#   'guess',
#   'like',
#   'thing',
#   'must',
#   'exist',
#   'like',
#   'rain',
#   'hail',
#   'mist',
#   'time',
#   'done',
#   'becom',
#   'one'],
#  ['aaooooright', 'work'],
#  ['im', 'leav', 'hous'],
#  ['hello',
#   'love',
#   'get',
#   'interview',
#   'today',
#   'happi',
#   'good',
#   'boy',
#   'think',
#   'mear',
#   'miss'],
#  ['custom',
#   'servic',
#   'annonc',
#   'new',
#   'year',
#   'deliveri',
#   'wait',
#   'plea',
#   'call',
#   'arrang',
#   'deliveri'],
#  ['winner',
#   'special',
#   'select',
#   'receiv',
#   'cash',
#   'holiday',
#   'flight',
#   'inc',
#   'speak',
#   'live',
#   'oper',
#   'claim'],
#  ['keep',
#   'safe',
#   'need',
#   'miss',
#   'alreadi',
#   'envi',
#   'everyon',
#   'see',
#   'real',
#   'life'],
#  ['new', 'car', 'hous', 'parentsi', 'new', 'job', 'hand'],
#  ['im', 'love', 'im', 'excit', 'day', 'spend', 'make', 'happi'],
#  ['pls',
#   'stop',
#   'bootydeli',
#   'invit',
#   'friend',
#   'repli',
#   'yes',
#   'no',
#   'see',
#   'stop',
#   'send',
#   'stop',
#   'frnd'],
#  ['bangbab',
#   'ur',
#   'order',
#   'way',
#   'receiv',
#   'servic',
#   'msg',
#   'download',
#   'ur',
#   'content',
#   'goto',
#   'wap',
#   'bangb',
#   'tv',
#   'ur',
#   'mobil',
#   'internetservic',
#   'menu'],
#  ['place', 'ur', 'point', 'cultur', 'modul', 'alreadi'],
#  ['urgent',
#   'tri',
#   'contact',
#   'last',
#   'weekend',
#   'draw',
#   'show',
#   'prize',
#   'guarante',
#   'call',
#   'claim',
#   'code',
#   'valid',
#   'hrs'],
#  ['hi', 'frnd', 'best', 'way', 'avoid', 'missunderstd', 'wit', 'belov', 'one'],
#  ['great', 'escap', 'fanci', 'bridg', 'need', 'lager', 'see', 'tomo'],
#  ['yes', 'complet', 'formclark', 'also', 'utter', 'wast'],
#  ['sir', 'need', 'axi', 'bank', 'account', 'bank', 'address'],
#  ['hmmm',
#   'thk',
#   'sure',
#   'got',
#   'time',
#   'hop',
#   'ard',
#   'ya',
#   'go',
#   'free',
#   'abt',
#   'muz',
#   'call',
#   'discus',
#   'liao'],
#  ['time', 'come', 'later'],
#  ['bloodi',
#   'hell',
#   'cant',
#   'believ',
#   'forgot',
#   'surnam',
#   'mr',
#   'ill',
#   'give',
#   'clue',
#   'spanish',
#   'begin'],
#  ['well', 'im', 'gon', 'na', 'finish', 'bath', 'goodfin', 'night'],
#  ['let', 'know', 'youv', 'got', 'money', 'carlo', 'make', 'call'],
#  ['still', 'go', 'mall'],
#  ['turn',
#   'friend',
#   'stay',
#   'whole',
#   'show',
#   'wont',
#   'back',
#   'til',
#   'ltgt',
#   'feel',
#   'free',
#   'go',
#   'ahead',
#   'smoke',
#   'ltgt',
#   'worth'],
#  ['text', 'doesnt', 'repli', 'let', 'know', 'log'],
#  ['hi',
#   'spoke',
#   'maneesha',
#   'wed',
#   'like',
#   'know',
#   'satisfi',
#   'experi',
#   'repli',
#   'toll',
#   'free',
#   'yes'],
#  ['lift',
#   'hope',
#   'offer',
#   'money',
#   'need',
#   'especi',
#   'end',
#   'month',
#   'approach',
#   'hurt',
#   'studi',
#   'anyway',
#   'gr',
#   'weekend'],
#  ['lol', 'trust'],
#  ['ok', 'gentleman', 'treat', 'digniti', 'respect'],
#  ['guy', 'close'],
#  ['go', 'noth', 'greatby'],
#  ['hello',
#   'handsom',
#   'find',
#   'job',
#   'lazi',
#   'work',
#   'toward',
#   'get',
#   'back',
#   'net',
#   'mummi',
#   'boytoy',
#   'miss'],
#  ['haha', 'awesom', 'minut'],
#  ['plea',
#   'call',
#   'custom',
#   'servic',
#   'repres',
#   'freephon',
#   'am',
#   'pm',
#   'guarante',
#   'cash',
#   'prize'],
#  ['got', 'xmas', 'radio', 'time', 'get'],
#  ['jus',
#   'reach',
#   'home',
#   'go',
#   'bath',
#   'first',
#   'si',
#   'use',
#   'net',
#   'tell',
#   'finish'],
#  ['uniqu', 'enough', 'find', 'th', 'august'],
#  ['im',
#   'sorri',
#   'ive',
#   'join',
#   'leagu',
#   'peopl',
#   'dont',
#   'keep',
#   'touch',
#   'mean',
#   'great',
#   'deal',
#   'friend',
#   'time',
#   'even',
#   'great',
#   'person',
#   'cost',
#   'great',
#   'week'],
#  ['hi', 'final', 'complet', 'cours'],
#  ['stop',
#   'howev',
#   'suggest',
#   'stay',
#   'someon',
#   'abl',
#   'give',
#   'everi',
#   'stool'],
#  ['hope', 'youv', 'settl', 'new', 'school', 'year', 'wishin', 'gr', 'day'],
#  ['gud', 'mrng', 'dear', 'hav', 'nice', 'day'],
#  ['got', 'person', 'stori'],
#  ['hamster', 'dead', 'hey', 'tmr', 'meet', 'pm', 'orchard', 'mrt'],
#  ['hi',
#   'kate',
#   'even',
#   'hope',
#   'see',
#   'tomorrow',
#   'bit',
#   'bloodi',
#   'babyjontet',
#   'txt',
#   'back',
#   'xxx'],
#  ['found', 'enc', 'ltgt'],
#  ['sent', 'ltgt', 'buck'],
#  ['hello',
#   'darlin',
#   'ive',
#   'finish',
#   'colleg',
#   'txt',
#   'finish',
#   'love',
#   'kate',
#   'xxx'],
#  ['account',
#   'refil',
#   'success',
#   'inr',
#   'ltdecimalgt',
#   'keralacircl',
#   'prepaid',
#   'account',
#   'balanc',
#   'ltdecimalgt',
#   'transact',
#   'id',
#   'kr',
#   'ltgt'],
#  ['goodmorn', 'sleep', 'ga'],
#  ['call', 'alter', 'ok'],
#  ['say', 'like', 'dat', 'dun', 'buy', 'ericsson', 'oso', 'oredi', 'lar'],
#  ['enter',
#   'cabin',
#   'pa',
#   'said',
#   'happi',
#   'bday',
#   'bos',
#   'felt',
#   'special',
#   'askd',
#   'lunch',
#   'lunch',
#   'invit',
#   'apart',
#   'went'],
#  ['aight', 'yo', 'dat', 'straight', 'dogg'],
#  ['plea', 'give', 'connect', 'today', 'ltdecimalgt', 'refund', 'bill'],
#  ['shoot', 'big', 'load', 'get', 'readi'],
#  ['bruv', 'hope', 'great', 'break', 'reward', 'semest'],
#  ['home', 'alway', 'chat'],
#  ['kkgoodstudi', 'well'],
#  ['yup', 'noe', 'leh'],
#  ['sound', 'great', 'home'],
#  ['final', 'match', 'head', 'toward', 'draw', 'predict'],
#  ['tire', 'havent', 'slept', 'well', 'past', 'night'],
#  ['easi', 'ahsen', 'got', 'select', 'mean', 'good'],
#  ['take', 'exam', 'march'],
#  ['yeah',
#   'think',
#   'use',
#   'gt',
#   'atm',
#   'regist',
#   'sure',
#   'anyway',
#   'help',
#   'let',
#   'know',
#   'sure',
#   'readi'],
#  ['ok', 'prob', 'take', 'ur', 'time'],
#  ['call',
#   'ubandu',
#   'run',
#   'without',
#   'instal',
#   'hard',
#   'diskyou',
#   'use',
#   'copi',
#   'import',
#   'file',
#   'system',
#   'give',
#   'repair',
#   'shop'],
#  ['sorri', 'ill', 'call', 'later'],
#  ['say',
#   'leh',
#   'cours',
#   'noth',
#   'happen',
#   'lar',
#   'say',
#   'romant',
#   'jus',
#   'bit',
#   'lor',
#   'thk',
#   'nite',
#   'sceneri',
#   'nice',
#   'leh'],
#  ['new',
#   'mobil',
#   'must',
#   'go',
#   'txt',
#   'nokia',
#   'collect',
#   'todayfrom',
#   'www',
#   'tcbiz',
#   'optout',
#   'gbpmtmsg'],
#  ['would', 'realli', 'appreci', 'call', 'need', 'someon', 'talk'],
#  ['meet',
#   'ur',
#   'dream',
#   'partner',
#   'soon',
#   'ur',
#   'career',
#   'flyng',
#   'start',
#   'find',
#   'free',
#   'txt',
#   'horo',
#   'follow',
#   'ur',
#   'star',
#   'sign',
#   'horo',
#   'ari'],
#  ['hey', 'compani', 'elama', 'po', 'mudyadhu'],
#  ['life',
#   'strict',
#   'teacher',
#   'bcoz',
#   'teacher',
#   'teach',
#   'lesson',
#   'amp',
#   'conduct',
#   'exam',
#   'life',
#   'first',
#   'conduct',
#   'exam',
#   'amp',
#   'teach',
#   'lesson',
#   'happi',
#   'morn'],
#  ['dear', 'good', 'morn'],
#  ['get',
#   'gandhipuram',
#   'walk',
#   'cross',
#   'cut',
#   'road',
#   'right',
#   'side',
#   'ltgt',
#   'street',
#   'road',
#   'turn',
#   'first',
#   'right'],
#  ['dear', 'go', 'rubber', 'place'],
#  ['sorri', 'batteri', 'die', 'yeah', 'im'],
#  ['yesher', 'tv', 'alway', 'avail', 'work', 'place'],
#  ['text',
#   'meet',
#   'someon',
#   'sexi',
#   'today',
#   'find',
#   'date',
#   'even',
#   'flirt',
#   'join',
#   'repli',
#   'name',
#   'age',
#   'eg',
#   'sam',
#   'msg',
#   'recdthirtyeight',
#   'penc'],
#  ['print', 'oh', 'ltgt', 'come', 'upstair'],
#  ['ill', 'littl', 'closer', 'like', 'bus', 'stop', 'street'],
#  ['youwhen', 'wil', 'reach'],
#  ['new',
#   'theori',
#   'argument',
#   'win',
#   'situat',
#   'lose',
#   'person',
#   'dont',
#   'argu',
#   'ur',
#   'friend',
#   'kick',
#   'amp',
#   'say',
#   'im',
#   'alway',
#   'correct'],
#  ['secret',
#   'admir',
#   'look',
#   'make',
#   'contact',
#   'ufind',
#   'rreveal',
#   'think',
#   'ur',
#   'specialcal'],
#  ['tomarrow', 'final', 'hear', 'laptop', 'case', 'cant'],
#  ['tel', 'avent', 'done', 'sportsx'],
#  ['okay', 'shine', 'meant', 'sign', 'sound', 'better'],
#  ['although',
#   'told',
#   'dat',
#   'im',
#   'baig',
#   'face',
#   'watch',
#   'realli',
#   'like',
#   'watch',
#   'gave',
#   'co',
#   'fr',
#   'thanx',
#   'everyth',
#   'dat',
#   'uve',
#   'done',
#   'today',
#   'im',
#   'touch'],
#  ['dont', 'rememb', 'old', 'commerci'],
#  ['late', 'said', 'websit', 'didnt', 'dont', 'slipper'],
#  ['ask', 'call', 'ok'],
#  ['kalli', 'wont', 'bat', 'nd', 'inning'],
#  ['didnt',
#   'work',
#   'oh',
#   'ok',
#   'goodnight',
#   'ill',
#   'fix',
#   'readi',
#   'time',
#   'wake',
#   'dear',
#   'miss',
#   'good',
#   'night',
#   'sleep'],
#  ['congratul',
#   'ur',
#   'award',
#   'cd',
#   'voucher',
#   'gift',
#   'guarante',
#   'free',
#   'entri',
#   'wkli',
#   'draw',
#   'txt',
#   'music',
#   'tncs',
#   'wwwldewcom',
#   'win',
#   'ppmx',
#   'age'],
#  ['ranjith', 'cal', 'drpd', 'deeraj', 'deepak', 'min', 'hold'],
#  ['wen',
#   'ur',
#   'lovabl',
#   'bcum',
#   'angri',
#   'wid',
#   'dnt',
#   'take',
#   'serious',
#   'coz',
#   'angri',
#   'childish',
#   'true',
#   'way',
#   'show',
#   'deep',
#   'affect',
#   'care',
#   'luv',
#   'kettoda',
#   'manda',
#   'nice',
#   'day',
#   'da'],
#  ['doinghow'],
#  ['day',
#   'also',
#   'ship',
#   'compani',
#   'take',
#   'wks',
#   'way',
#   'usp',
#   'take',
#   'week',
#   'get',
#   'lag',
#   'may',
#   'bribe',
#   'nipost',
#   'get',
#   'stuff'],
#  ['im', 'back', 'lem', 'know', 'readi'],
#  ['dont',
#   'necessarili',
#   'expect',
#   'done',
#   'get',
#   'back',
#   'though',
#   'im',
#   'headin'],
#  ['mmm', 'yummi', 'babe', 'nice', 'jolt', 'suzi'],
#  ['lover', 'need'],
#  ['tri',
#   'contact',
#   'repli',
#   'offer',
#   'video',
#   'handset',
#   'anytim',
#   'network',
#   'min',
#   'unlimit',
#   'text',
#   'camcord',
#   'repli',
#   'call'],
#  ['park', 'next', 'mini', 'come', 'today', 'think'],
#  ['yup'],
#  ['anyway',
#   'im',
#   'go',
#   'shop',
#   'co',
#   'si',
#   'done',
#   'yet',
#   'dun',
#   'disturb',
#   'liao'],
#  ['luton', 'ring', 'ur', 'around'],
#  ['hey',
#   'realli',
#   'horni',
#   'want',
#   'chat',
#   'see',
#   'nake',
#   'text',
#   'hot',
#   'text',
#   'charg',
#   'pm',
#   'unsubscrib',
#   'text',
#   'stop'],
#  ['dint', 'come'],
#  ['wana', 'plan', 'trip', 'sometm'],
#  ['sure', 'yet', 'still', 'tri', 'get', 'hold'],
#  ['ur',
#   'rington',
#   'servic',
#   'chang',
#   'free',
#   'credit',
#   'go',
#   'club',
#   'mobilescom',
#   'choos',
#   'content',
#   'stop',
#   'txt',
#   'club',
#   'stop',
#   'pwk',
#   'club',
#   'po',
#   'box',
#   'mk',
#   'wt'],
#  ['evo', 'download', 'flash', 'jealous'],
#  ['rington',
#   'club',
#   'get',
#   'uk',
#   'singl',
#   'chart',
#   'mobil',
#   'week',
#   'choos',
#   'top',
#   'qualiti',
#   'rington',
#   'messag',
#   'free',
#   'charg'],
#  ['come', 'mu', 'sort', 'narcot', 'situat'],
#  ['night',
#   'end',
#   'anoth',
#   'day',
#   'morn',
#   'come',
#   'special',
#   'way',
#   'may',
#   'smile',
#   'like',
#   'sunni',
#   'ray',
#   'leav',
#   'worri',
#   'blue',
#   'blue',
#   'bay'],
#  ['hmv',
#   'bonus',
#   'special',
#   'pound',
#   'genuin',
#   'hmv',
#   'voucher',
#   'answer',
#   'easi',
#   'question',
#   'play',
#   'send',
#   'hmv',
#   'infowww',
#   'percentrealcom'],
#  ['usf', 'guess', 'might', 'well', 'take', 'car'],
#  ['object', 'bf', 'come'],
#  ['thanx'],
#  ['tell', 'rob', 'mack', 'gf', 'theater'],
#  ['awesom', 'ill', 'see', 'bit'],
#  ['sent', 'type', 'food', 'like'],
#  ['done', 'hand', 'celebr', 'full', 'swing', 'yet'],
#  ['got', 'call', 'tool'],
#  ['wen',
#   'miss',
#   'someon',
#   'person',
#   'definit',
#   'special',
#   'person',
#   'special',
#   'miss',
#   'keepintouch',
#   'gdeve'],
#  ['ok', 'ask', 'money', 'far'],
#  ['oki'],
#  ['yeah',
#   'think',
#   'usual',
#   'guy',
#   'still',
#   'pas',
#   'last',
#   'night',
#   'get',
#   'ahold',
#   'anybodi',
#   'let',
#   'know',
#   'ill',
#   'throw'],
#  ['might', 'come', 'tonight', 'class', 'let', 'earli'],
#  ['ok'],
#  ['hi',
#   'babi',
#   'im',
#   'cruisin',
#   'girl',
#   'friend',
#   'give',
#   'call',
#   'hour',
#   'home',
#   'alright',
#   'fone',
#   'fone',
#   'love',
#   'jenni',
#   'xxx'],
#  ['life',
#   'mean',
#   'lot',
#   'love',
#   'life',
#   'love',
#   'peopl',
#   'life',
#   'world',
#   'call',
#   'friend',
#   'call',
#   'world',
#   'ge'],
#  ['dearshal',
#   'mail',
#   'tonitebusi',
#   'streetshal',
#   'updat',
#   'toniteth',
#   'look',
#   'okvarunnathu',
#   'edukkukaye',
#   'raksha',
#   'ollubut',
#   'good',
#   'one',
#   'real',
#   'sen'],
#  ['hey', 'told', 'name', 'gautham', 'ah'],
#  ['haf', 'found', 'feel', 'stupid', 'da', 'cam', 'work'],
#  ['oop', 'got', 'bit'],
#  ['much', 'buzi'],
#  ['accident', 'delet', 'messag', 'resend', 'plea'],
#  ['tmobil',
#   'custom',
#   'may',
#   'claim',
#   'free',
#   'camera',
#   'phone',
#   'upgrad',
#   'pay',
#   'go',
#   'sim',
#   'card',
#   'loyalti',
#   'call',
#   'offer',
#   'end',
#   'thfebtc',
#   'appli'],
#  ['unless', 'situat', 'go', 'gurl', 'would', 'appropri'],
#  ['hurt',
#   'tea',
#   'make',
#   'cri',
#   'end',
#   'life',
#   'die',
#   'plz',
#   'keep',
#   'one',
#   'rose',
#   'grave',
#   'say',
#   'stupid',
#   'miss',
#   'nice',
#   'day',
#   'bslvyl'],
#  ['cant', 'pick', 'phone', 'right', 'pls', 'send', 'messag'],
#  ['need', 'coffe', 'run', 'tomoc', 'believ', 'time', 'week', 'alreadi'],
#  ['awesom',
#   'rememb',
#   'last',
#   'time',
#   'got',
#   'somebodi',
#   'high',
#   'first',
#   'time',
#   'diesel'],
#  ['shit',
#   'realli',
#   'shock',
#   'scari',
#   'cant',
#   'imagin',
#   'second',
#   'def',
#   'night',
#   'think',
#   'somewher',
#   'could',
#   'crash',
#   'night',
#   'save',
#   'taxi'],
#  ['oh', 'way', 'food', 'fridg', 'want', 'go', 'meal', 'tonight'],
#  ['womdarful', 'actor'],
#  ['sm',
#   'ac',
#   'blind',
#   'date',
#   'rodds',
#   'aberdeen',
#   'unit',
#   'kingdom',
#   'check',
#   'httpimg',
#   'sm',
#   'acwicmb',
#   'cktz',
#   'blind',
#   'date',
#   'send',
#   'hide'],
#  ['yup', 'remb', 'think', 'book'],
#  ['jos', 'ask', 'wana', 'meet'],
#  ['lol',
#   'yes',
#   'friendship',
#   'hang',
#   'thread',
#   'caus',
#   'wont',
#   'buy',
#   'stuff'],
#  ['themob',
#   'check',
#   'newest',
#   'select',
#   'content',
#   'game',
#   'tone',
#   'gossip',
#   'babe',
#   'sport',
#   'keep',
#   'mobil',
#   'fit',
#   'funki',
#   'text',
#   'wap'],
#  ['garag', 'key', 'arent', 'bookshelf'],
#  ['today',
#   'accept',
#   'dayu',
#   'accept',
#   'brother',
#   'sister',
#   'lover',
#   'dear',
#   'best',
#   'clos',
#   'lvblefrnd',
#   'jstfrnd',
#   'cutefrnd',
#   'lifpartnr',
#   'belovd',
#   'swtheart',
#   'bstfrnd',
#   'rpli',
#   'mean',
#   'enemi'],
#  ['think',
#   'ur',
#   'smart',
#   'win',
#   'week',
#   'week',
#   'quiz',
#   'text',
#   'play',
#   'nowtc',
#   'winnersclub',
#   'po',
#   'box',
#   'uz',
#   'gbp',
#   'week'],
#  ['say',
#   'hell',
#   'give',
#   'call',
#   'friend',
#   'got',
#   'money',
#   'he',
#   'definit',
#   'buy',
#   'end',
#   'week'],
#  ['hi',
#   'way',
#   'day',
#   'normal',
#   'waythi',
#   'real',
#   'ur',
#   'uniquei',
#   'hope',
#   'know',
#   'rest',
#   'mylif',
#   'hope',
#   'find',
#   'wot',
#   'lost'],
#  ['made', 'day', 'great', 'day'],
#  ['kkadvanc', 'happi', 'pongal'],
#  ['hmmm',
#   'guess',
#   'go',
#   'kb',
#   'power',
#   'yoga',
#   'haha',
#   'dunno',
#   'tahan',
#   'power',
#   'yoga',
#   'anot',
#   'thk',
#   'got',
#   'lo',
#   'oso',
#   'forgot',
#   'liao'],
#  ['realli', 'dude', 'friend', 'im', 'afraid'],
#  ['decemb',
#   'mobil',
#   'mths',
#   'entitl',
#   'updat',
#   'latest',
#   'colour',
#   'camera',
#   'mobil',
#   'free',
#   'call',
#   'mobil',
#   'updat',
#   'co',
#   'free'],
#  ['coffe', 'cake', 'guess'],
#  ['merri', 'christma', 'babe', 'love', 'ya', 'kiss'],
#  ['hey', 'dont', 'go', 'watch', 'men', 'lunch', 'haha'],
#  ['cud',
#   'tell',
#   'ppl',
#   'im',
#   'gona',
#   'bit',
#   'co',
#   'buse',
#   'hav',
#   'gon',
#   'past',
#   'co',
#   'full',
#   'im',
#   'still',
#   'waitin',
#   'pete'],
#  ['would',
#   'great',
#   'well',
#   'guild',
#   'could',
#   'meet',
#   'bristol',
#   'road',
#   'somewher',
#   'get',
#   'touch',
#   'weekend',
#   'plan',
#   'take',
#   'flight',
#   'good',
#   'week'],
#  ['problem'],
#  ['call'],
#  ['hi', 'dahow', 'today', 'class'],
#  ['id',
#   'say',
#   'good',
#   'sign',
#   'well',
#   'know',
#   'track',
#   'record',
#   'read',
#   'woman'],
#  ['cool', 'text', 'park'],
#  ['im', 'read', 'text', 'sent', 'meant', 'joke', 'read', 'light'],
#  ['kkapo', 'kgood', 'movi'],
#  ['mayb', 'could', 'get', 'book', 'tomo', 'return', 'immedi', 'someth'],
#  ['call',
#   'germani',
#   'penc',
#   'per',
#   'minut',
#   'call',
#   'fix',
#   'line',
#   'via',
#   'access',
#   'number',
#   'prepay',
#   'direct',
#   'access'],
#  ['chanc',
#   'might',
#   'evapor',
#   'soon',
#   'violat',
#   'privaci',
#   'steal',
#   'phone',
#   'number',
#   'employ',
#   'paperwork',
#   'cool',
#   'plea',
#   'contact',
#   'report',
#   'supervisor'],
#  ['valentin',
#   'day',
#   'special',
#   'win',
#   'quiz',
#   'take',
#   'partner',
#   'trip',
#   'lifetim',
#   'send',
#   'go',
#   'pmsg',
#   'rcvd',
#   'custcare'],
#  ['tadaaaaa', 'home', 'babe', 'still'],
#  ['cool', 'come', 'havent', 'wine', 'dine'],
#  ['sleepingand', 'surf'],
#  ['sorri', 'ill', 'call', 'later'],
#  ['call', 'right', 'call', 'hand', 'phone'],
#  ['ok', 'great', 'thanx', 'lot'],
#  ['take',
#   'post',
#   'come',
#   'must',
#   'text',
#   'happi',
#   'read',
#   'one',
#   'wiv',
#   'hello',
#   'carolin',
#   'end',
#   'favourit',
#   'bless'],
#  ['hide', 'stranger'],
#  ['interest', 'like'],
#  ['sister', 'clear', 'two', 'round', 'birla', 'soft', 'yesterday'],
#  ['go'],
#  ['dis',
#   'yiju',
#   'jus',
#   'saw',
#   'ur',
#   'mail',
#   'case',
#   'huim',
#   'havent',
#   'sent',
#   'num',
#   'dis',
#   'num'],
#  ['one', 'small', 'prestig', 'problem'],
#  ['fanci',
#   'shag',
#   'dointerest',
#   'sextextukcom',
#   'txt',
#   'xxuk',
#   'suzi',
#   'txts',
#   'cost',
#   'per',
#   'msg',
#   'tncs',
#   'websit'],
#  ['check', 'realli', 'miss', 'see', 'jeremiah', 'great', 'month'],
#  ['nah', 'cant', 'help', 'ive', 'never', 'iphon'],
#  ['car', 'hour', 'half', 'im', 'go', 'apeshit'],
#  ['today',
#   'sorri',
#   'day',
#   'ever',
#   'angri',
#   'ever',
#   'misbehav',
#   'hurt',
#   'plz',
#   'plz',
#   'slap',
#   'urself',
#   'bcoz',
#   'ur',
#   'fault',
#   'im',
#   'basic',
#   'good'],
#  ['yo',
#   'guy',
#   'ever',
#   'figur',
#   'much',
#   'need',
#   'alcohol',
#   'jay',
#   'tri',
#   'figur',
#   'much',
#   'safe',
#   'spend',
#   'weed'],
#  ['ltgt', 'ish', 'minut', 'minut', 'ago', 'wtf'],
#  ['thank',
#   'callingforgot',
#   'say',
#   'happi',
#   'onam',
#   'sirjii',
#   'fine',
#   'rememb',
#   'met',
#   'insur',
#   'personmeet',
#   'qatar',
#   'insha',
#   'allahrakhesh',
#   'ex',
#   'tata',
#   'aig',
#   'join',
#   'tisscotays'],
#  ['congratul',
#   'ur',
#   'award',
#   'cd',
#   'voucher',
#   'gift',
#   'guarante',
#   'free',
#   'entri',
#   'wkli',
#   'draw',
#   'txt',
#   'music',
#   'tncs',
#   'wwwldewcom',
#   'win',
#   'ppmx',
#   'age'],
#  ['ur',
#   'cashbal',
#   'current',
#   'pound',
#   'maxim',
#   'ur',
#   'cashin',
#   'send',
#   'cash',
#   'pmsg',
#   'cc',
#   'hgsuite',
#   'land',
#   'roww',
#   'hl'],
#  ['im',
#   'actor',
#   'work',
#   'work',
#   'even',
#   'sleep',
#   'late',
#   'sinc',
#   'im',
#   'unemploy',
#   'moment',
#   'alway',
#   'sleep',
#   'late',
#   'unemploy',
#   'everi',
#   'day',
#   'saturday'],
#  ['hello', 'got', 'st', 'andrewsboy', 'long', 'way', 'cold', 'keep', 'post'],
#  ['ha', 'ha', 'cool', 'cool', 'chikku', 'chikkudb'],
#  ['oh', 'ok', 'prob'],
#  ['check', 'audrey', 'status', 'right'],
#  ['busi', 'tri', 'finish', 'new', 'year', 'look', 'forward', 'final', 'meet'],
#  ['good',
#   'afternoon',
#   'sunshin',
#   'dawn',
#   'day',
#   'refresh',
#   'happi',
#   'aliv',
#   'breath',
#   'air',
#   'smile',
#   'think',
#   'love',
#   'alway'],
#  ['well', 'know', 'take', 'care', 'worri'],
#  ['updatenow',
#   'xmas',
#   'offer',
#   'latest',
#   'motorola',
#   'sonyericsson',
#   'nokia',
#   'free',
#   'bluetooth',
#   'doubl',
#   'min',
#   'txt',
#   'orang',
#   'call',
#   'mobileupd',
#   'call',
#   'optoutf'],
#  ['discount',
#   'code',
#   'rp',
#   'stop',
#   'messag',
#   'repli',
#   'stop',
#   'custom',
#   'servic'],
#  ['wat', 'uniform', 'get'],
#  ['cool', 'text', 'readi'],
#  ['hello',
#   'boytoy',
#   'geeee',
#   'miss',
#   'alreadi',
#   'woke',
#   'wish',
#   'bed',
#   'cuddl',
#   'love'],
#  ['spoil', 'bed', 'well'],
#  ['im', 'go', 'bath', 'msg', 'next', 'ltgt', 'min'],
#  ['cant',
#   'keep',
#   'talk',
#   'peopl',
#   'sure',
#   'pay',
#   'agre',
#   'price',
#   'pls',
#   'tell',
#   'want',
#   'realli',
#   'buy',
#   'much',
#   'pay'],
#  ['thank',
#   'rington',
#   'order',
#   'refer',
#   'charg',
#   'gbp',
#   'per',
#   'week',
#   'unsubscrib',
#   'anytim',
#   'call',
#   'custom',
#   'servic'],
#  ['say', 'happen'],
#  ['could', 'seen', 'mei', 'didt', 'recognis', 'face'],
#  ['well',
#   'lot',
#   'thing',
#   'happen',
#   'lindsay',
#   'new',
#   'year',
#   'sigh',
#   'bar',
#   'ptbo',
#   'blue',
#   'heron',
#   'someth',
#   'go'],
#  ['keep', 'payasam', 'rinu', 'bring'],
#  ['taught',
#   'ranjith',
#   'sir',
#   'call',
#   'sm',
#   'like',
#   'becaus',
#   'he',
#   'verifi',
#   'project',
#   'prabu',
#   'told',
#   'today',
#   'pa',
#   'dont',
#   'mistak'],
#  ['guess',
#   'worri',
#   'must',
#   'know',
#   'way',
#   'bodi',
#   'repair',
#   'im',
#   'quit',
#   'sure',
#   'shouldnt',
#   'worri',
#   'well',
#   'take',
#   'slow',
#   'first',
#   'test',
#   'guid',
#   'ovul',
#   'relax',
#   'noth',
#   'youv',
#   'said',
#   'reason',
#   'worri',
#   'ill',
#   'keep',
#   'followin'],
#  ['yeah', 'sure', 'give', 'coupl', 'minut', 'track', 'wallet'],
#  ['hey', 'leav', 'big', 'deal', 'take', 'care'],
#  ['hey', 'late', 'ah', 'meet'],
#  ['doubl',
#   'min',
#   'txts',
#   'month',
#   'free',
#   'bluetooth',
#   'orang',
#   'avail',
#   'soni',
#   'nokia',
#   'motorola',
#   'phone',
#   'call',
#   'mobileupd',
#   'call',
#   'optoutn',
#   'dx'],
#  ['took', 'mr', 'owl', 'lick'],
#  ['custom', 'place', 'call'],
#  ['mm', 'time', 'dont', 'like', 'fun'],
#  ['mths',
#   'half',
#   'price',
#   'orang',
#   'line',
#   'rental',
#   'latest',
#   'camera',
#   'phone',
#   'free',
#   'phone',
#   'mths',
#   'call',
#   'mobilesdirect',
#   'free',
#   'updat',
#   'or',
#   'stoptxt'],
#  ['yup', 'lunch', 'buffet', 'eat', 'alreadi'],
#  ['huh', 'late', 'fr', 'dinner'],
#  ['hey', 'sat', 'go', 'intro', 'pilat', 'kickbox'],
#  ['morn', 'ok'],
#  ['yes',
#   'think',
#   'offic',
#   'lap',
#   'room',
#   'think',
#   'last',
#   'day',
#   'didnt',
#   'shut'],
#  ['pick', 'bout', 'ish', 'time', 'go'],
#  ['perform',
#   'award',
#   'calcul',
#   'everi',
#   'two',
#   'monthnot',
#   'current',
#   'one',
#   'month',
#   'period'],
#  ['actual',
#   'sleep',
#   'still',
#   'might',
#   'call',
#   'back',
#   'text',
#   'gr',
#   'rock',
#   'si',
#   'send',
#   'text',
#   'wen',
#   'wake'],
#  ['alway',
#   'put',
#   'busi',
#   'put',
#   'pictur',
#   'as',
#   'facebook',
#   'one',
#   'open',
#   'peopl',
#   'ive',
#   'ever',
#   'met',
#   'would',
#   'think',
#   'pictur',
#   'room',
#   'would',
#   'hurt',
#   'make',
#   'feel',
#   'violat'],
#  ['good',
#   'even',
#   'sir',
#   'al',
#   'salam',
#   'wahleykkumshar',
#   'happi',
#   'newsbi',
#   'grace',
#   'god',
#   'got',
#   'offer',
#   'tayseertissco',
#   'joinedhop',
#   'fineinshah',
#   'allahmeet',
#   'india'],
#  ['hmmmkbut',
#   'want',
#   'chang',
#   'field',
#   'quick',
#   'dai',
#   'wan',
#   'na',
#   'get',
#   'system',
#   'administr',
#   'network',
#   'administr'],
#  ['free',
#   'rington',
#   'text',
#   'first',
#   'poli',
#   'text',
#   'get',
#   'true',
#   'tone',
#   'help',
#   'st',
#   'free',
#   'tone',
#   'pw',
#   'nd',
#   'txt',
#   'stop'],
#  ['dear', 'chechi', 'talk'],
#  ['hair', 'cream', 'ship'],
#  ['none', 'happen', 'til', 'get', 'though'],
#  ['yep',
#   'great',
#   'loxahatche',
#   'xmas',
#   'tree',
#   'burn',
#   'ltgt',
#   'start',
#   'hour'],
#  ['haha', 'get', 'use', 'drive', 'usf', 'man', 'know', 'lot', 'stoner'],
#  ['well',
#   'slight',
#   'disastr',
#   'class',
#   'pm',
#   'fav',
#   'darl',
#   'hope',
#   'day',
#   'ok',
#   'coffe',
#   'wld',
#   'good',
#   'cant',
#   'stay',
#   'late',
#   'tomorrow',
#   'time',
#   'place',
#   'alway'],
#  ['hello', 'good', 'week', 'fanci', 'drink', 'someth', 'later'],
#  ['headin', 'toward', 'busetop'],
#  ['messagesom',
#   'text',
#   'miss',
#   'sendernam',
#   'miss',
#   'number',
#   'miss',
#   'sentdat',
#   'miss',
#   'miss',
#   'lot',
#   'everyth',
#   'miss',
#   'sent',
#   'via',
#   'fullonsmscom'],
#  ['come', 'room', 'point', 'iron', 'plan', 'weekend'],
#  ['co', 'want', 'thing'],
#  ['oki',
#   'ill',
#   'go',
#   'yan',
#   'jiu',
#   'skip',
#   'ard',
#   'oso',
#   'go',
#   'cine',
#   'den',
#   'go',
#   'mrt',
#   'one',
#   'blah',
#   'blah',
#   'blah'],
#  ['bring', 'home', 'wendi'],
#  ['date', 'servic', 'call', 'box', 'sk', 'ch'],
#  ['whatsup', 'dont', 'want', 'sleep'],
#  ['alright', 'new', 'goal'],
#  ['free',
#   'entri',
#   'week',
#   'competit',
#   'text',
#   'word',
#   'win',
#   'tc',
#   'wwwtxttowincouk'],
#  ['alright', 'ill', 'head', 'minut', 'text', 'meet'],
#  ['send',
#   'logo',
#   'ur',
#   'lover',
#   'name',
#   'join',
#   'heart',
#   'txt',
#   'love',
#   'name',
#   'name',
#   'mobno',
#   'eg',
#   'love',
#   'adam',
#   'eve',
#   'yahoo',
#   'pobox',
#   'wq',
#   'txtno',
#   'ad'],
#  ['yesfrom', 'last', 'week', 'im', 'take', 'live', 'call'],
#  ['someon',
#   'contact',
#   'date',
#   'servic',
#   'enter',
#   'phone',
#   'fanci',
#   'find',
#   'call',
#   'landlin',
#   'pobox',
#   'tf'],
#  ['siva', 'hostel', 'aha'],
#  ['urgent',
#   'mobil',
#   'number',
#   'award',
#   'prize',
#   'guarante',
#   'call',
#   'land',
#   'line',
#   'claim',
#   'valid',
#   'hrs'],
#  ['send',
#   'ur',
#   'friend',
#   'receiv',
#   'someth',
#   'ur',
#   'voic',
#   'speak',
#   'express',
#   'childish',
#   'naughti',
#   'sentiment',
#   'rowdi',
#   'ful',
#   'attitud',
#   'romant',
#   'shi',
#   'attract',
#   'funni',
#   'ltgt',
#   'irrit',
#   'ltgt',
#   'lovabl',
#   'repli'],
#  ['ok', 'shell', 'ok', 'guess'],
#  ['aathiwher', 'dear'],
#  ['pain', 'urin', 'thing', 'el'],
#  ['esplanad', 'mind', 'give', 'lift', 'co', 'got', 'car', 'today'],
#  ['wnt',
#   'buy',
#   'bmw',
#   'car',
#   'urgentlyit',
#   'vri',
#   'urgentbut',
#   'hv',
#   'shortag',
#   'ltgt',
#   'lacsther',
#   'sourc',
#   'arng',
#   'dis',
#   'amt',
#   'ltgt',
#   'lacsthat',
#   'prob'],
#  ['home', 'watch', 'tv', 'lor'],
#  ['usual', 'take', 'fifteen', 'fuck', 'minut', 'respond', 'yes', 'question'],
#  ['congrat',
#   'nokia',
#   'video',
#   'camera',
#   'phone',
#   'call',
#   'call',
#   'cost',
#   'ppm',
#   'ave',
#   'call',
#   'min',
#   'vari',
#   'mobil',
#   'close',
#   'post',
#   'bcm',
#   'ldn',
#   'wc',
#   'xx'],
#  ['book', 'ticket', 'pongal'],
#  ['avail',
#   'im',
#   'like',
#   'right',
#   'around',
#   'hillsborough',
#   'amp',
#   'ltgt',
#   'th'],
#  ['messag', 'sent', 'askin', 'ltgt', 'dollar', 'shoul', 'pay', 'ltgt', 'ltgt'],
#  ['ask', 'iouri', 'ive', 'told', 'stori', 'like', 'ten', 'time', 'alreadi'],
#  ['long', 'applebe', 'fuck', 'take'],
#  ['hi', 'hope', 'get', 'txtjourney', 'hasnt', 'gdnow', 'min', 'late', 'think'],
#  ['like', 'love', 'arrang'],
#  ['yesh',
#   'realli',
#   'greatbhaji',
#   'told',
#   'kalli',
#   'best',
#   'cricket',
#   'sachin',
#   'worldveri',
#   'tough',
#   'get'],
#  ['suppos', 'wake', 'gt'],
#  ['oic', 'saw', 'tot', 'din', 'found', 'group', 'liao'],
#  ['sorri', 'ill', 'call', 'later'],
#  ['hey',
#   'hey',
#   'wereth',
#   'monkeespeopl',
#   'say',
#   'monkeyaround',
#   'howdi',
#   'gorgeous',
#   'howu',
#   'doin',
#   'foundurself',
#   'jobyet',
#   'sausagelov',
#   'jen',
#   'xxx'],
#  ['sorri', 'batteri', 'die', 'come', 'im', 'get', 'gram', 'place'],
#  ['well',
#   'done',
#   'blimey',
#   'exercis',
#   'yeah',
#   'kinda',
#   'rememb',
#   'wot',
#   'hmm'],
#  ['wont', 'get', 'concentr', 'dear', 'know', 'mind', 'everyth'],
#  ['lol', 'made', 'plan', 'new', 'year'],
#  ['min', 'later'],
#  ['hank', 'lotsli'],
#  ['thank', 'hope', 'good', 'day', 'today'],
#  ['kkwhat', 'detail', 'want', 'transferacc', 'enough'],
#  ['ok',
#   'tell',
#   'stay',
#   'yeah',
#   'tough',
#   'optimist',
#   'thing',
#   'improv',
#   'month'],
#  ['loan',
#   'purpos',
#   'homeown',
#   'tenant',
#   'welcom',
#   'previous',
#   'refus',
#   'still',
#   'help',
#   'call',
#   'free',
#   'text',
#   'back',
#   'help'],
#  ['si', 'si', 'think', 'ill', 'go', 'make', 'oreo', 'truffl'],
#  ['look',
#   'ami',
#   'ure',
#   'beauti',
#   'intellig',
#   'woman',
#   'like',
#   'lot',
#   'know',
#   'don',
#   'like',
#   'like',
#   'don',
#   'worri'],
#  ['hope',
#   'result',
#   'consist',
#   'intellig',
#   'kind',
#   'start',
#   'ask',
#   'practicum',
#   'link',
#   'keep',
#   'ear',
#   'open',
#   'best',
#   'ttyl'],
#  ['call',
#   'cost',
#   'guess',
#   'isnt',
#   'bad',
#   'miss',
#   'ya',
#   'need',
#   'ya',
#   'want',
#   'ya',
#   'love',
#   'ya'],
#  ['go',
#   'thru',
#   'differ',
#   'feelingwav',
#   'decis',
#   'cope',
#   'individualtim',
#   'heal',
#   'everyth',
#   'believ'],
#  ['go', 'phone', 'gon', 'na', 'die', 'stay'],
#  ['great', 'never', 'better', 'day', 'give', 'even', 'reason', 'thank', 'god'],
#  ['upgrdcentr',
#   'orang',
#   'custom',
#   'may',
#   'claim',
#   'free',
#   'camera',
#   'phone',
#   'upgrad',
#   'loyalti',
#   'call',
#   'offer',
#   'end',
#   'th',
#   'juli',
#   'tc',
#   'appli',
#   'optout',
#   'avail'],
#  ['sorri', 'ill', 'call', 'later', 'ok', 'bye'],
#  ['ok', 'way', 'railway'],
#  ['great',
#   'princess',
#   'love',
#   'give',
#   'receiv',
#   'oral',
#   'doggi',
#   'style',
#   'fave',
#   'posit',
#   'enjoy',
#   'make',
#   'love',
#   'ltgt',
#   'time',
#   'per',
#   'night'],
#  ['dont', 'put', 'stuff', 'road', 'keep', 'get', 'slipperi'],
#  ['go', 'ride', 'bike'],
#  ['yup', 'need', 'ill', 'jus', 'wait', 'rain', 'stop'],
#  ['mani', 'compani', 'tell', 'languag'],
#  ['okmail',
#   'dear',
#   'dave',
#   'final',
#   'notic',
#   'collect',
#   'tenerif',
#   'holiday',
#   'cash',
#   'award',
#   'call',
#   'landlin',
#   'tc',
#   'sae',
#   'box',
#   'cw',
#   'wx',
#   'ppm'],
#  ['long', 'sinc', 'scream', 'princess'],
#  ['noth',
#   'meant',
#   'money',
#   'enter',
#   'account',
#   'bank',
#   'remov',
#   'flat',
#   'rate',
#   'someon',
#   'transfer',
#   'ltgt',
#   'account',
#   'ltgt',
#   'dollar',
#   'got',
#   'remov',
#   'bank',
#   'differ',
#   'charg',
#   'also',
#   'differb',
#   'sure',
#   'trust',
#   'ja',
#   'person',
#   'send',
#   'account',
#   'detail',
#   'co'],
#  ['want',
#   'get',
#   'laid',
#   'tonight',
#   'want',
#   'real',
#   'dog',
#   'locat',
#   'sent',
#   'direct',
#   'ur',
#   'mob',
#   'join',
#   'uk',
#   'largest',
#   'dog',
#   'network',
#   'txting',
#   'moan',
#   'nyt',
#   'ec',
#   'pmsg'],
#  ['nice',
#   'line',
#   'said',
#   'broken',
#   'heart',
#   'plz',
#   'dont',
#   'cum',
#   'time',
#   'infront',
#   'wise',
#   'trust',
#   'good'],
#  ['ok', 'im', 'gon', 'na', 'head', 'usf', 'like', 'fifteen', 'minut'],
#  ['love', 'aathilov', 'lot'],
#  ['tension', 'ahwhat', 'machiani', 'problem'],
#  ['pick', 'anoth', 'th', 'done'],
#  ['whenr', 'guy', 'get', 'back', 'said', 'think', 'stay', 'mcr'],
#  ['almost', 'see', 'sec'],
#  ['yo', 'carlo', 'friend', 'alreadi', 'ask', 'work', 'weekend'],
#  ['watch', 'tv', 'lor'],
#  ['thank', 'babi', 'cant', 'wait', 'tast', 'real', 'thing'],
#  ['chang', 'fb', 'jaykwon', 'thuglyf', 'falconerf'],
#  ['win', 'realli', 'side', 'long', 'time'],
#  ['free',
#   'messag',
#   'activ',
#   'free',
#   'text',
#   'messag',
#   'repli',
#   'messag',
#   'word',
#   'free',
#   'term',
#   'condit',
#   'visit',
#   'www',
#   'com'],
#  ['dear', 'reach', 'railway', 'happen'],
#  ['depend',
#   'qualiti',
#   'want',
#   'type',
#   'sent',
#   'boy',
#   'fade',
#   'glori',
#   'want',
#   'ralph',
#   'mayb'],
#  ['think', 'ive', 'fix', 'send', 'test', 'messag'],
#  ['sorri',
#   'man',
#   'account',
#   'dri',
#   'would',
#   'want',
#   'could',
#   'trade',
#   'back',
#   'half',
#   'could',
#   'buy',
#   'shit',
#   'credit',
#   'card'],
#  ['congrat',
#   'year',
#   'special',
#   'cinema',
#   'pas',
#   'call',
#   'suprman',
#   'matrix',
#   'starwars',
#   'etc',
#   'free',
#   'bx',
#   'ip',
#   'pm',
#   'dont',
#   'miss'],
#  ['sorryin', 'meet', 'ill', 'call', 'later'],
#  ['class', 'ltgt', 'reunion'],
#  ['free', 'nowcan', 'call'],
#  ['got', 'meh'],
#  ['nope', 'think', 'go', 'monday', 'sorri', 'repli', 'late'],
#  ['told', 'accentur', 'confirm', 'true'],
#  ['kate', 'jackson', 'rec', 'center', 'ish', 'right'],
#  ['dear', 'reach', 'room'],
#  ['fight',
#   'world',
#   'easi',
#   'either',
#   'win',
#   'lose',
#   'bt',
#   'fightng',
#   'some',
#   'close',
#   'dificult',
#   'lose',
#   'lose',
#   'win',
#   'still',
#   'lose'],
#  ['come'],
#  ['check', 'nuerologist'],
#  ['lolnic', 'went', 'fish', 'water'],
#  ['congratul',
#   'week',
#   'competit',
#   'draw',
#   'prize',
#   'claim',
#   'call',
#   'tcsstop',
#   'sm',
#   'ppm'],
#  ['wait',
#   'car',
#   'dat',
#   'bore',
#   'wat',
#   'co',
#   'wait',
#   'outsid',
#   'got',
#   'noth',
#   'home',
#   'stuff',
#   'watch',
#   'tv',
#   'wat'],
#  ['mayb', 'westshor', 'hyde', 'park', 'villag', 'place', 'near', 'hous'],
#  ['know',
#   'anthoni',
#   'bring',
#   'money',
#   'ive',
#   'school',
#   'fee',
#   'pay',
#   'rent',
#   'stuff',
#   'like',
#   'need',
#   'help',
#   'friend',
#   'need'],
#  ['signific'],
#  ['opinion',
#   'jada',
#   'kusruthi',
#   'lovabl',
#   'silent',
#   'spl',
#   'charact',
#   'matur',
#   'stylish',
#   'simpl',
#   'pls',
#   'repli'],
#  ['latest', 'still', 'scroung', 'ammo', 'want', 'give', 'new', 'ak', 'tri'],
#  ['prabhaim', 'sorydarealyfrm', 'heart', 'im', 'sorus'],
#  ['lol', 'ok', 'forgiven'],
#  ['nojst', 'chang', 'tat'],
#  ['guarante',
#   'latest',
#   'nokia',
#   'phone',
#   'gb',
#   'ipod',
#   'mp',
#   'player',
#   'prize',
#   'txt',
#   'word',
#   'collect',
#   'ibhltd',
#   'ldnw',
#   'pmtmsgrcvd'],
#  ['sno', 'competit'],
#  ['boltblu',
#   'tone',
#   'repli',
#   'poli',
#   'mono',
#   'eg',
#   'poly',
#   'cha',
#   'cha',
#   'slide',
#   'yeah',
#   'slow',
#   'jamz',
#   'toxic',
#   'come',
#   'stop',
#   'tone',
#   'txt'],
#  ['credit', 'top', 'renew', 'pin', 'tgxxrz'],
#  ['way',
#   'transport',
#   'less',
#   'problemat',
#   'sat',
#   'night',
#   'way',
#   'want',
#   'ask',
#   'join',
#   'bday',
#   'feel',
#   'free',
#   'need',
#   'know',
#   'definit',
#   'no',
#   'book',
#   'fri'],
#  ['usual',
#   'person',
#   'unconsci',
#   'child',
#   'adult',
#   'may',
#   'behav',
#   'abnorm',
#   'ill',
#   'call'],
#  ['ebay', 'might', 'less', 'elsewher'],
#  ['shall', 'come', 'get', 'pickl'],
#  ['gon', 'na', 'go', 'get', 'taco'],
#  ['rude', 'campus'],
#  ['urgent',
#   'mobil',
#   'award',
#   'bonus',
#   'caller',
#   'prize',
#   'nd',
#   'attempt',
#   'contact',
#   'call',
#   'box',
#   'qu'],
#  ['hi', 'wont', 'ard', 'christma', 'enjoy', 'merri', 'xmas'],
#  ['today',
#   'offer',
#   'claim',
#   'ur',
#   'worth',
#   'discount',
#   'voucher',
#   'text',
#   'yes',
#   'savamob',
#   'member',
#   'offer',
#   'mobil',
#   'sub',
#   'unsub',
#   'repli'],
#  ['yes', 'pretti', 'ladi', 'like', 'singl'],
#  ['reciev',
#   'tone',
#   'within',
#   'next',
#   'hrs',
#   'term',
#   'condit',
#   'plea',
#   'see',
#   'channel',
#   'teletext',
#   'pg'],
#  ['jay', 'say', 'doublefaggot'],
#  ['privat',
#   'account',
#   'statement',
#   'show',
#   'unredeem',
#   'sim',
#   'point',
#   'call',
#   'identifi',
#   'code',
#   'expir'],
#  ['holidayso', 'work'],
#  ['go'],
#  ['ill', 'late'],
#  ['ive',
#   'call',
#   'hope',
#   'malaria',
#   'know',
#   'miss',
#   'guy',
#   'miss',
#   'ban',
#   'big',
#   'pls',
#   'give',
#   'love',
#   'especi',
#   'great',
#   'day'],
#  ['good',
#   'afternoon',
#   'love',
#   'goe',
#   'day',
#   'hope',
#   'mayb',
#   'got',
#   'lead',
#   'job',
#   'think',
#   'boytoy',
#   'send',
#   'passion',
#   'kiss',
#   'across',
#   'sea'],
#  ['probabl', 'gon', 'na', 'see', 'later', 'tonight', 'lt'],
#  ['mayb', 'fat', 'finger', 'press', 'button', 'doesnt', 'know'],
#  ['ummmmmaah',
#   'mani',
#   'mani',
#   'happi',
#   'return',
#   'day',
#   'dear',
#   'sweet',
#   'heart',
#   'happi',
#   'birthday',
#   'dear'],
#  ['tirupur', 'da', 'start', 'offic', 'call'],
#  ['pmsg', 'max', 'month', 'tcsc', 'web', 'age', 'stop', 'txt', 'stop'],
#  ['famous',
#   'quot',
#   'develop',
#   'abil',
#   'listen',
#   'anyth',
#   'uncondit',
#   'without',
#   'lose',
#   'temper',
#   'self',
#   'confid',
#   'mean',
#   'marri'],
#  ['go', 'colleg', 'pa', 'el', 'ill', 'come', 'self', 'pa'],
#  ['oclock', 'mine', 'bash', 'flat', 'plan'],
#  ['girl',
#   'stay',
#   'bed',
#   'girl',
#   'doesnt',
#   'need',
#   'recoveri',
#   'time',
#   'id',
#   'rather',
#   'pas',
#   'fun',
#   'coop',
#   'bed'],
#  ['special'],
#  ['know',
#   'need',
#   'get',
#   'hotel',
#   'got',
#   'invit',
#   'apologis',
#   'cali',
#   'sweet',
# ...
#   'plea',
#   'go',
#   'tscs',
#   'appli',
#   'stop',
#   'text',
#   'txt',
#   'stop'],
#  ['thank',
#   'much',
#   'skype',
#   'wit',
#   'kz',
#   'sura',
#   'didnt',
#   'get',
#   'pleasur',
#   'compani',
#   'hope',
#   'good',
#   'weve',
#   'given',
#   'ultimatum',
#   'oh',
#   'countin',
#   'aburo',
#   'enjoy',
#   'messag',
#   'sent',
#   'day',
#   'ago'],
#  ['sure', 'result', 'offer'],
#  ['good', 'morn', 'dear', 'great', 'amp', 'success', 'day'],
#  ['want',
#   'anytim',
#   'network',
#   'min',
#   'text',
#   'new',
#   'video',
#   'phone',
#   'five',
#   'pound',
#   'per',
#   'week',
#   'call',
#   'repli',
#   'deliveri',
#   'tomorrow'],
#  ['sir',
#   'late',
#   'pay',
#   'rent',
#   'past',
#   'month',
#   'pay',
#   'ltgt',
#   'charg',
#   'felt',
#   'would',
#   'inconsider',
#   'nag',
#   'someth',
#   'give',
#   'great',
#   'cost',
#   'didnt',
#   'speak',
#   'howev',
#   'recess',
#   'wont',
#   'abl',
#   'pay',
#   'charg',
#   'month',
#   'henc',
#   'askin',
#   'well',
#   'ahead',
#   'month',
#   'end',
#   'plea',
#   'help',
#   'thank'],
#  ['tri',
#   'contact',
#   'offer',
#   'new',
#   'video',
#   'phone',
#   'anytim',
#   'network',
#   'min',
#   'half',
#   'price',
#   'rental',
#   'camcord',
#   'call',
#   'repli',
#   'deliveri',
#   'wed'],
#  ['last',
#   'chanc',
#   'claim',
#   'ur',
#   'worth',
#   'discount',
#   'voucherstext',
#   'yes',
#   'nowsavamobmemb',
#   'offer',
#   'mobil',
#   'sub',
#   'remov',
#   'txt',
#   'stop'],
#  ['luv',
#   'soo',
#   'much',
#   'don',
#   'understand',
#   'special',
#   'ring',
#   'morrow',
#   'luv',
#   'xxx'],
#  ['pls', 'send', 'comprehens', 'mail', 'im', 'pay', 'much'],
#  ['prashanthettan',
#   'mother',
#   'pas',
#   'away',
#   'last',
#   'night',
#   'pray',
#   'famili'],
#  ['urgent',
#   'call',
#   'landlin',
#   'complimentari',
#   'ibiza',
#   'holiday',
#   'cash',
#   'await',
#   'collect',
#   'sae',
#   'tc',
#   'po',
#   'box',
#   'sk',
#   'wp',
#   'ppm'],
#  ['kkwhen', 'go'],
#  ['meanwhil',
#   'shit',
#   'suit',
#   'xavier',
#   'decid',
#   'give',
#   'ltgt',
#   'second',
#   'warn',
#   'samantha',
#   'come',
#   'play',
#   'jay',
#   'guitar',
#   'impress',
#   'shit',
#   'also',
#   'dont',
#   'think',
#   'doug',
#   'realiz',
#   'dont',
#   'live',
#   'anymor'],
#  ['stomach',
#   'thru',
#   'much',
#   'trauma',
#   'swear',
#   'cant',
#   'eat',
#   'better',
#   'lose',
#   'weight'],
#  ['officewhat', 'mattermsg', 'nowi', 'call', 'break'],
#  ['yeah',
#   'bare',
#   'enough',
#   'room',
#   'two',
#   'mani',
#   'fuck',
#   'shoe',
#   'sorri',
#   'man',
#   'see',
#   'later'],
#  ['today',
#   'offer',
#   'claim',
#   'ur',
#   'worth',
#   'discount',
#   'voucher',
#   'text',
#   'yes',
#   'savamob',
#   'member',
#   'offer',
#   'mobil',
#   'sub',
#   'unsub',
#   'repli'],
#  ['reach', 'orchard', 'alreadi', 'wan', 'go', 'buy', 'ticket', 'first'],
#  ['real', 'babi', 'want', 'bring', 'inner', 'tigress'],
#  ['da', 'run', 'activ', 'full', 'version', 'da'],
#  ['ah',
#   'poor',
#   'babyhop',
#   'urfeel',
#   'bettersn',
#   'luv',
#   'probthat',
#   'overdos',
#   'work',
#   'hey',
#   'go',
#   'care',
#   'spk',
#   'sn',
#   'lot',
#   'lovejen',
#   'xxx'],
#  ['stop', 'stori', 'ive', 'told', 'ive', 'return', 'he', 'say', 'order'],
#  ['talk',
#   'sexi',
#   'make',
#   'new',
#   'friend',
#   'fall',
#   'love',
#   'world',
#   'discreet',
#   'text',
#   'date',
#   'servic',
#   'text',
#   'vip',
#   'see',
#   'could',
#   'meet'],
#  ['go', 'take', 'babe'],
#  ['hai',
#   'ana',
#   'tomarrow',
#   'come',
#   'morn',
#   'ltdecimalgt',
#   'ill',
#   'sathi',
#   'go',
#   'rto',
#   'offic',
#   'repli',
#   'came',
#   'home'],
#  ['spoon', 'okay'],
#  ['say', 'somebodi', 'name', 'tampa'],
#  ['work', 'go', 'min'],
#  ['brother', 'genius'],
#  ['sorri',
#   'guess',
#   'whenev',
#   'get',
#   'hold',
#   'connect',
#   'mayb',
#   'hour',
#   'two',
#   'ill',
#   'text'],
#  ['find', 'time', 'bus', 'coz', 'need', 'sort', 'stuff'],
#  ['dude', 'ive', 'see', 'lotta', 'corvett', 'late'],
#  ['congratul',
#   'ur',
#   'award',
#   'either',
#   'yr',
#   'suppli',
#   'cd',
#   'virgin',
#   'record',
#   'mysteri',
#   'gift',
#   'guarante',
#   'call',
#   'tscs',
#   'wwwsmsconet',
#   'pm',
#   'approx',
#   'min'],
#  ['consid',
#   'wall',
#   'bunker',
#   'shit',
#   'import',
#   'never',
#   'play',
#   'peac',
#   'guess',
#   'place',
#   'high',
#   'enough',
#   'dont',
#   'matter'],
#  ['privat',
#   'account',
#   'statement',
#   'xxxxxx',
#   'show',
#   'unredeem',
#   'point',
#   'call',
#   'identifi',
#   'code',
#   'expir'],
#  ['hello',
#   'need',
#   'posh',
#   'bird',
#   'chap',
#   'user',
#   'trial',
#   'prod',
#   'champney',
#   'put',
#   'need',
#   'address',
#   'dob',
#   'asap',
#   'ta'],
#  ['want',
#   'xmas',
#   'free',
#   'text',
#   'messag',
#   'new',
#   'video',
#   'phone',
#   'half',
#   'price',
#   'line',
#   'rental',
#   'call',
#   'free',
#   'find'],
#  ['well',
#   'offici',
#   'philosoph',
#   'hole',
#   'wan',
#   'na',
#   'call',
#   'home',
#   'readi',
#   'save'],
#  ['go',
#   'goodno',
#   'problembut',
#   'still',
#   'need',
#   'littl',
#   'experi',
#   'understand',
#   'american',
#   'custom',
#   'voic'],
#  ['ill', 'text', 'drop'],
#  ['ugh', 'long', 'day', 'im', 'exhaust', 'want', 'cuddl', 'take', 'nap'],
#  ['talk',
#   'atleast',
#   'day',
#   'otherwis',
#   'miss',
#   'best',
#   'friend',
#   'world',
#   'shakespear',
#   'shesil',
#   'ltgt'],
#  ['shop',
#   'till',
#   'drop',
#   'either',
#   'cash',
#   'travel',
#   'voucher',
#   'call',
#   'ntt',
#   'po',
#   'box',
#   'cr',
#   'bt',
#   'fixedlin',
#   'cost',
#   'ppm',
#   'mobil',
#   'vari'],
#  ['castor', 'need', 'see', 'someth'],
#  ['sunshin',
#   'quiz',
#   'wkli',
#   'win',
#   'top',
#   'soni',
#   'dvd',
#   'player',
#   'know',
#   'countri',
#   'liverpool',
#   'play',
#   'mid',
#   'week',
#   'txt',
#   'ansr',
#   'sptyron'],
#  ['secret',
#   'admir',
#   'look',
#   'make',
#   'contact',
#   'ufind',
#   'rreveal',
#   'think',
#   'ur',
#   'specialcal'],
#  ['secret',
#   'admir',
#   'look',
#   'make',
#   'contact',
#   'ufind',
#   'rreveal',
#   'think',
#   'ur',
#   'specialcal',
#   'stopsms'],
#  ['remind',
#   'download',
#   'content',
#   'alreadi',
#   'paid',
#   'goto',
#   'httpdoit',
#   'mymobi',
#   'tv',
#   'collect',
#   'content'],
#  ['see',
#   'knew',
#   'give',
#   'break',
#   'time',
#   'woul',
#   'lead',
#   'alway',
#   'want',
#   'miss',
#   'curfew',
#   'gon',
#   'na',
#   'gibe',
#   'til',
#   'one',
#   'midnight',
#   'movi',
#   'gon',
#   'na',
#   'get',
#   'til',
#   'need',
#   'come',
#   'home',
#   'need',
#   'getsleep',
#   'anyth',
#   'need',
#   'studdi',
#   'ear',
#   'train'],
#  ['love', 'give', 'massag', 'use', 'lot', 'babi', 'oil', 'fave', 'posit'],
#  ['dude', 'go', 'sup'],
#  ['yoyyooo',
#   'know',
#   'chang',
#   'permiss',
#   'drive',
#   'mac',
#   'usb',
#   'flash',
#   'drive'],
#  ['gibb', 'unsoldmik', 'hussey'],
#  ['like', 'talk', 'pa', 'abl', 'dont', 'know'],
#  ['dun',
#   'cut',
#   'short',
#   'leh',
#   'dun',
#   'like',
#   'ah',
#   'fail',
#   'shes',
#   'quit',
#   'sad'],
#  ['unbeliev', 'faglord'],
#  ['wifehow', 'knew', 'time', 'murder', 'exact'],
#  ['ask', 'princess'],
#  ['great', 'princess', 'think'],
#  ['nutter', 'cutter', 'ctter', 'cttergg', 'cttargg', 'ctargg', 'ctagg', 'ie'],
#  ['ok',
#   'noe',
#   'ure',
#   'busi',
#   'im',
#   'realli',
#   'bore',
#   'msg',
#   'oso',
#   'dunno',
#   'wat',
#   'colour',
#   'choos',
#   'one'],
#  ['doesnt',
#   'class',
#   'earli',
#   'tomorrow',
#   'thus',
#   'shouldnt',
#   'tri',
#   'smoke',
#   'ltgt'],
#  ['superb',
#   'thought',
#   'grate',
#   'dont',
#   'everyth',
#   'want',
#   'mean',
#   'still',
#   'opportun',
#   'happier',
#   'tomorrow',
#   'today'],
#  ['hope', 'good', 'week', 'check'],
#  ['im',
#   'use',
#   'hope',
#   'agent',
#   'dont',
#   'drop',
#   'sinc',
#   'ive',
#   'book',
#   'thing',
#   'year',
#   'whole',
#   'boston',
#   'nyc',
#   'experi'],
#  ['thursday', 'night', 'yeah', 'sure', 'thing', 'well', 'work'],
#  ['free',
#   'rington',
#   'wait',
#   'collect',
#   'simpli',
#   'text',
#   'password',
#   'mix',
#   'verifi',
#   'get',
#   'usher',
#   'britney',
#   'fml',
#   'po',
#   'box',
#   'mk',
#   'ppw'],
#  ['probabl',
#   'money',
#   'worri',
#   'thing',
#   'come',
#   'due',
#   'sever',
#   'outstand',
#   'invoic',
#   'work',
#   'two',
#   'three',
#   'month',
#   'ago'],
#  ['possibl', 'teach'],
#  ['wonder', 'phone', 'batteri', 'went', 'dead', 'tell', 'love', 'babe'],
#  ['love', 'smell', 'bus', 'aint', 'tobacco'],
#  ['get', 'worri', 'derek', 'taylor', 'alreadi', 'assum', 'worst'],
#  ['hey', 'charl', 'sorri', 'late', 'repli'],
#  ['lastest',
#   'stereophon',
#   'marley',
#   'dizze',
#   'racal',
#   'libertin',
#   'stroke',
#   'win',
#   'nookii',
#   'game',
#   'flirt',
#   'click',
#   'themob',
#   'wap',
#   'bookmark',
#   'text',
#   'wap'],
#  ['ill', 'give', 'plus', 'said', 'grinul', 'greet', 'whenev', 'speak'],
#  ['white', 'fudg', 'oreo', 'store'],
#  ['januari',
#   'male',
#   'sale',
#   'hot',
#   'gay',
#   'chat',
#   'cheaper',
#   'call',
#   'nation',
#   'rate',
#   'pmin',
#   'cheap',
#   'pmin',
#   'peak',
#   'stop',
#   'text',
#   'call',
#   'pmin'],
#  ['love',
#   'come',
#   'took',
#   'long',
#   'leav',
#   'zaher',
#   'got',
#   'word',
#   'ym',
#   'happi',
#   'see',
#   'sad',
#   'left',
#   'miss'],
#  ['sorri', 'hurt'],
#  ['cant',
#   'feel',
#   'nauseous',
#   'im',
#   'piss',
#   'didnt',
#   'eat',
#   'sweet',
#   'week',
#   'caus',
#   'today',
#   'plan',
#   'pig',
#   'diet',
#   'week',
#   'im',
#   'hungri'],
#  ['ok', 'lor', 'earli', 'still', 'project', 'meet'],
#  ['call', 'da', 'wait', 'call'],
#  ['could', 'ask', 'carlo', 'could', 'get', 'anybodi', 'el', 'chip'],
#  ['actual', 'send', 'remind', 'today', 'wonder', 'weekend'],
#  ['peopl',
#   'see',
#   'msg',
#   'think',
#   'iam',
#   'addict',
#   'msging',
#   'wrong',
#   'bcoz',
#   'dont',
#   'know',
#   'iam',
#   'addict',
#   'sweet',
#   'friend',
#   'bslvyl'],
#  ['hey',
#   'gave',
#   'photo',
#   'regist',
#   'drive',
#   'ah',
#   'tmr',
#   'wan',
#   'na',
#   'meet',
#   'yck'],
#  ['dont', 'talk', 'ever', 'ok', 'word'],
#  ['wana', 'see'],
#  ['way', 'school', 'pls', 'send', 'ashley', 'number'],
#  ['shall', 'fine', 'avalarr', 'hollalat'],
#  ['went',
#   'attend',
#   'anoth',
#   'two',
#   'round',
#   'todaybut',
#   'still',
#   'didt',
#   'reach',
#   'home'],
#  ['actual', 'delet', 'old', 'websitenow', 'blog'],
#  ['wait', 'chikkuil', 'send', 'aftr', 'ltgt', 'min'],
#  ['im',
#   'diet',
#   'ate',
#   'mani',
#   'slice',
#   'pizza',
#   'yesterday',
#   'ugh',
#   'im',
#   'alway',
#   'diet'],
#  ['ki', 'give', 'kvb', 'acc', 'detail'],
#  ['oh', 'come', 'ah'],
#  ['money',
#   'lucki',
#   'winner',
#   'claim',
#   'prize',
#   'text',
#   'money',
#   'million',
#   'give',
#   'away',
#   'ppt',
#   'normal',
#   'text',
#   'rate',
#   'box',
#   'ji'],
#  ['im',
#   'realli',
#   'sorri',
#   'wont',
#   'abl',
#   'fridayhop',
#   'find',
#   'alternativehop',
#   'yr',
#   'term',
#   'go',
#   'ok'],
#  ['congratul',
#   'ore',
#   'mo',
#   'owo',
#   'wa',
#   'enjoy',
#   'wish',
#   'mani',
#   'happi',
#   'moment',
#   'fro',
#   'wherev',
#   'go'],
#  ['samus', 'shoulder', 'yet'],
#  ['time', 'think', 'youll', 'need', 'know', 'near', 'campus'],
#  ['dear',
#   'matthew',
#   'plea',
#   'call',
#   'landlin',
#   'complimentari',
#   'lux',
#   'tenerif',
#   'holiday',
#   'cash',
#   'await',
#   'collect',
#   'ppm',
#   'sae',
#   'tc',
#   'box',
#   'sk',
#   'xh'],
#  ['dun', 'wear', 'jean', 'lor'],
#  ['sinc', 'side', 'fever', 'vomitin'],
#  ['kkare', 'colleg'],
#  ['urgent',
#   'call',
#   'landlin',
#   'complimentari',
#   'tenerif',
#   'holiday',
#   'cash',
#   'await',
#   'collect',
#   'sae',
#   'tc',
#   'box',
#   'hp',
#   'yf',
#   'ppm'],
#  ['better',
#   'made',
#   'friday',
#   'stuf',
#   'like',
#   'pig',
#   'yesterday',
#   'feel',
#   'bleh',
#   'least',
#   'writh',
#   'pain',
#   'kind',
#   'bleh'],
#  ['sell',
#   'well',
#   'ton',
#   'coin',
#   'sell',
#   'coin',
#   'someon',
#   'thru',
#   'paypal',
#   'voila',
#   'money',
#   'back',
#   'life',
#   'pocket'],
#  ['theyr', 'lot', 'place', 'hospit', 'medic', 'place', 'safe'],
#  ['get',
#   'touch',
#   'folk',
#   'wait',
#   'compani',
#   'txt',
#   'back',
#   'name',
#   'age',
#   'opt',
#   'enjoy',
#   'communiti',
#   'psms'],
#  ['also',
#   'ive',
#   'sorta',
#   'blown',
#   'coupl',
#   'time',
#   'recent',
#   'id',
#   'rather',
#   'text',
#   'blue',
#   'look',
#   'weed'],
#  ['sent',
#   'score',
#   'sopha',
#   'secondari',
#   'applic',
#   'school',
#   'think',
#   'think',
#   'appli',
#   'research',
#   'cost',
#   'also',
#   'contact',
#   'joke',
#   'ogunrind',
#   'school',
#   'one',
#   'less',
#   'expens',
#   'one'],
#  ['cant', 'wait', 'see', 'photo', 'use'],
#  ['ur',
#   'cashbal',
#   'current',
#   'pound',
#   'maxim',
#   'ur',
#   'cashin',
#   'send',
#   'go',
#   'pmsg',
#   'cc',
#   'po',
#   'box',
#   'tcrw'],
#  ['hey',
#   'book',
#   'kb',
#   'sat',
#   'alreadi',
#   'lesson',
#   'go',
#   'ah',
#   'keep',
#   'sat',
#   'night',
#   'free',
#   'need',
#   'meet',
#   'confirm',
#   'lodg'],
#  ['chk', 'ur', 'belovd', 'dict'],
#  ['time', 'want', 'come'],
#  ['awesom', 'lem', 'know', 'whenev', 'around'],
#  ['shb', 'ok', 'lor', 'thanx'],
#  ['beauti',
#   'truth',
#   'graviti',
#   'read',
#   'care',
#   'heart',
#   'feel',
#   'light',
#   'someon',
#   'feel',
#   'heavi',
#   'someon',
#   'leav',
#   'good',
#   'night'],
#  ['also', 'rememb', 'get', 'dobbi', 'bowl', 'car'],
#  ['filthi', 'stori', 'girl', 'wait'],
#  ['sorri',
#   'ur',
#   'msg',
#   'yar',
#   'lor',
#   'poor',
#   'thing',
#   'one',
#   'night',
#   'tmr',
#   'ull',
#   'brand',
#   'new',
#   'room',
#   'sleep'],
#  ['love',
#   'isnt',
#   'decis',
#   'feel',
#   'could',
#   'decid',
#   'love',
#   'life',
#   'would',
#   'much',
#   'simpler',
#   'less',
#   'magic'],
#  ['welp', 'appar', 'retir'],
#  ['sort',
#   'code',
#   'acc',
#   'bank',
#   'natwest',
#   'repli',
#   'confirm',
#   'ive',
#   'sent',
#   'right',
#   'person'],
#  ['sure', 'cant', 'take', 'sick', 'time'],
#  ['urgent',
#   'tri',
#   'contact',
#   'today',
#   'draw',
#   'show',
#   'prize',
#   'guarante',
#   'call',
#   'land',
#   'line',
#   'claim',
#   'valid',
#   'hr'],
#  ['watch',
#   'cartoon',
#   'listen',
#   'music',
#   'amp',
#   'eve',
#   'go',
#   'templ',
#   'amp',
#   'church'],
#  ['yo',
#   'chad',
#   'gymnast',
#   'class',
#   'wan',
#   'na',
#   'take',
#   'site',
#   'say',
#   'christian',
#   'class',
#   'full'],
#  ['much', 'buzi'],
#  ['better', 'still', 'catch', 'let', 'ask', 'sell', 'ltgt'],
#  ['sure', 'night', 'menu', 'know', 'noon', 'menu'],
#  ['want',
#   'come',
#   'backa',
#   'beauti',
#   'necklac',
#   'token',
#   'heart',
#   'youthat',
#   'give',
#   'wife',
#   'likingb',
#   'seeno',
#   'one',
#   'give',
#   'thatdont',
#   'call',
#   'mei',
#   'wait',
#   'till',
#   'come'],
#  ['go', 'aptitud', 'class'],
#  ['wont', 'tri', 'sort', 'hous', 'ok'],
#  ['yar',
#   'lor',
#   'wan',
#   'go',
#   'hors',
#   'race',
#   'today',
#   'mah',
#   'eat',
#   'earlier',
#   'lor',
#   'ate',
#   'chicken',
#   'rice'],
#  ['haha', 'awesom', 'omw', 'back'],
#  ['yup', 'thk', 'shop', 'close', 'lor'],
#  ['account', 'number'],
#  ['eh', 'send', 'wrong', 'lar'],
#  ['hey',
#   'ad',
#   'crap',
#   'nite',
#   'borin',
#   'without',
#   'ya',
#   'boggi',
#   'bore',
#   'biatch',
#   'thanx',
#   'wait',
#   'til',
#   'nxt',
#   'time',
#   'il',
#   'ave',
#   'ya'],
#  ['ok', 'shall', 'talk'],
#  ['dont',
#   'hesit',
#   'know',
#   'second',
#   'time',
#   'weak',
#   'like',
#   'keep',
#   'notebook',
#   'eat',
#   'day',
#   'anyth',
#   'chang',
#   'day',
#   'sure',
#   'noth'],
#  ['hey', 'pay', 'salari', 'de', 'ltgt'],
#  ['anoth', 'month', 'need', 'chocol', 'weed', 'alcohol'],
#  ['start', 'search', 'get', 'job', 'daysh', 'great', 'potenti', 'talent'],
#  ['reckon', 'need', 'town', 'eightish', 'walk', 'carpark'],
#  ['congrat',
#   'mobil',
#   'videophon',
#   'call',
#   'videochat',
#   'wid',
#   'mate',
#   'play',
#   'java',
#   'game',
#   'dload',
#   'polyph',
#   'music',
#   'nolin',
#   'rentl'],
#  ['look', 'fuckin', 'time', 'fuck', 'think'],
#  ['yo', 'guess', 'drop'],
#  ['carlo', 'say', 'hell', 'mu', 'ltgt', 'minut'],
#  ['im', 'offic', 'call', 'ltgt', 'min'],
#  ['geeee',
#   'miss',
#   'alreadi',
#   'know',
#   'think',
#   'fuck',
#   'cant',
#   'wait',
#   'till',
#   'next',
#   'year',
#   'togeth',
#   'love',
#   'kiss'],
#  ['yun',
#   'ahth',
#   'ubi',
#   'one',
#   'say',
#   'wan',
#   'call',
#   'tomorrowcal',
#   'look',
#   'ireneer',
#   'got',
#   'bus',
#   'ubi',
#   'cresubi',
#   'tech',
#   'park',
#   'ph',
#   'st',
#   'wkg',
#   'daysèn'],
#  ['ugh', 'got', 'ta', 'drive', 'back', 'sd', 'la', 'butt', 'sore'],
#  ['th', 'juli'],
#  ['hi',
#   'im',
#   'relax',
#   'time',
#   'ever',
#   'get',
#   'am',
#   'everi',
#   'day',
#   'parti',
#   'good',
#   'night',
#   'get',
#   'home',
#   'tomorrow',
#   'ish'],
#  ['wan', 'come', 'come', 'lor', 'din', 'stripe', 'skirt'],
#  ['xmas',
#   'stori',
#   'peac',
#   'xmas',
#   'msg',
#   'love',
#   'xmas',
#   'miracl',
#   'jesus',
#   'hav',
#   'bless',
#   'month',
#   'ahead',
#   'amp',
#   'wish',
#   'merri',
#   'xmas'],
#  ['cant', 'dont', 'number'],
#  ['chang', 'one', 'next', 'escal'],
#  ['yetund', 'im', 'class', 'run', 'water', 'make', 'ok', 'pls'],
#  ['lot',
#   'happen',
#   'feel',
#   'quiet',
#   'beth',
#   'aunt',
#   'charli',
#   'work',
#   'lot',
#   'helen',
#   'mo'],
#  ['wait',
#   'bus',
#   'stop',
#   'aft',
#   'ur',
#   'lect',
#   'lar',
#   'dun',
#   'go',
#   'get',
#   'car',
#   'come',
#   'back',
#   'pick'],
#  ['aight', 'thank', 'comin'],
#  ...]

# %%
### Lets train Word2vec from scratch
model=gensim.models.Word2Vec(sentences,window=5,min_count=2)
model.wv.index_to_key
# Out:
# ['call',
#  'im',
#  'go',
#  'get',
#  'ur',
#  'come',
#  'dont',
#  'free',
#  'ok',
#  'ltgt',
#  'know',
#  'day',
#  'like',
#  'got',
#  'love',
#  'want',
#  'ill',
#  'time',
#  'good',
#  'text',
#  'send',
#  'need',
#  'one',
#  'see',
#  'today',
#  'think',
#  'txt',
#  'stop',
#  'home',
#  'week',
#  'take',
#  'lor',
#  'repli',
#  'sorri',
#  'tell',
#  'still',
#  'mobil',
#  'back',
#  'make',
#  'phone',
#  'say',
#  'new',
#  'work',
#  'hi',
#  'plea',
#  'well',
#  'later',
#  'da',
#  'ask',
#  'miss',
#  'hope',
#  'cant',
#  'meet',
#  'happi',
#  'night',
#  'give',
#  'tri',
#  'dear',
#  'claim',
#  'thing',
#  'wait',
#  'great',
#  'much',
#  'oh',
#  'hey',
#  'pls',
#  'wat',
#  'number',
#  'messag',
#  'na',
#  'friend',
#  'thank',
#  'way',
#  'msg',
#  'min',
#  'right',
#  'prize',
#  'wan',
#  'feel',
#  'even',
#  'yes',
#  'let',
#  'pick',
#  'tomorrow',
#  'alreadi',
#  'win',
#  'said',
#  'yeah',
#  'realli',
#  'amp',
#  'leav',
#  'care',
#  'co',
#  'babe',
#  'morn',
#  'didnt',
#  'life',
#  'last',
#  'year',
#  'sure',
#  'servic',
#  'find',
#  'keep',
#  'would',
#  'anyth',
#  'nokia',
#  'contact',
#  'cash',
#  'ive',
#  'buy',
#  'sleep',
#  'tone',
#  'lol',
#  'everi',
#  'look',
#  'also',
#  'smile',
#  'wish',
#  'use',
#  'start',
#  'someth',
#  'watch',
#  'show',
#  'end',
#  'sent',
#  'award',
#  'finish',
#  'urgent',
#  'help',
#  'box',
#  'place',
#  'gud',
#  'person',
#  'guy',
#  'tonight',
#  'custom',
#  'next',
#  'first',
#  'went',
#  'someon',
#  'talk',
#  'around',
#  'could',
#  'chat',
#  'collect',
#  'gon',
#  'soon',
#  'mani',
#  'per',
#  'late',
#  'plan',
#  'alway',
#  'nice',
#  'live',
#  'money',
#  'word',
#  'minut',
#  'name',
#  'wont',
#  'ya',
#  'check',
#  'pm',
#  'dun',
#  'special',
#  'month',
#  'st',
#  'told',
#  'lot',
#  'hour',
#  'mean',
#  'tc',
#  'th',
#  'guarante',
#  'shop',
#  'reach',
#  'peopl',
#  'happen',
#  'girl',
#  'hello',
#  'yet',
#  'thk',
#  'best',
#  'ppm',
#  'done',
#  'haha',
#  'offer',
#  'thought',
#  'may',
#  'fuck',
#  'class',
#  'cost',
#  'play',
#  'havent',
#  'bit',
#  'line',
#  'receiv',
#  'fine',
#  'man',
#  'job',
#  'stuff',
#  'never',
#  'heart',
#  'lunch',
#  'car',
#  'eat',
#  'draw',
#  'holiday',
#  'enjoy',
#  'mayb',
#  'yup',
#  'account',
#  'pobox',
#  'drive',
#  'mind',
#  'guess',
#  'better',
#  'long',
#  'readi',
#  'sm',
#  'dat',
#  'cool',
#  'god',
#  'worri',
#  'pay',
#  'problem',
#  'chanc',
#  'wonder',
#  'latest',
#  'quit',
#  'weekend',
#  'half',
#  'boy',
#  'bring',
#  'room',
#  'luv',
#  'hous',
#  'game',
#  'po',
#  'noth',
#  'lar',
#  'book',
#  'date',
#  'anoth',
#  'big',
#  'real',
#  'yo',
#  'voucher',
#  'shit',
#  'landlin',
#  'put',
#  'sweet',
#  'camera',
#  'charg',
#  'world',
#  'stay',
#  'kiss',
#  'birthday',
#  'select',
#  'dinner',
#  'sir',
#  'liao',
#  'ever',
#  'xxx',
#  'speak',
#  'jus',
#  'join',
#  'actual',
#  'question',
#  'might',
#  'hear',
#  'rememb',
#  'network',
#  'probabl',
#  'pic',
#  'two',
#  'earli',
#  'fun',
#  'appli',
#  'point',
#  'nd',
#  'he',
#  'hurt',
#  'final',
#  'aight',
#  'chang',
#  'princess',
#  'den',
#  'age',
#  'video',
#  'babi',
#  'answer',
#  'thanx',
#  'bed',
#  'rate',
#  'pa',
#  'bad',
#  'part',
#  'run',
#  'id',
#  'forgot',
#  'anyway',
#  'orang',
#  'gift',
#  'walk',
#  'nite',
#  'rington',
#  'code',
#  'left',
#  'dunno',
#  'made',
#  'easi',
#  'wake',
#  'everyth',
#  'ah',
#  'littl',
#  'bus',
#  'dad',
#  'dis',
#  'enough',
#  'bore',
#  'pain',
#  'face',
#  'sound',
#  'leh',
#  'pound',
#  'school',
#  'shall',
#  'mate',
#  'wk',
#  'shes',
#  'yr',
#  'tmr',
#  'bt',
#  'sat',
#  'lose',
#  'dream',
#  'detail',
#  'await',
#  'without',
#  'tv',
#  'read',
#  'movi',
#  'land',
#  'xmas',
#  'afternoon',
#  'credit',
#  'must',
#  'pmin',
#  'decid',
#  'sexi',
#  'mail',
#  'test',
#  'hav',
#  'town',
#  'import',
#  'post',
#  'wif',
#  'came',
#  'sinc',
#  'price',
#  'abl',
#  'goe',
#  'smoke',
#  'true',
#  'okay',
#  'hrs',
#  'though',
#  'uk',
#  'entri',
#  'lesson',
#  'doesnt',
#  'valid',
#  'set',
#  'abt',
#  'offic',
#  'mob',
#  'bath',
#  'el',
#  'til',
#  'enter',
#  'plz',
#  'juz',
#  'wen',
#  'updat',
#  'wife',
#  'order',
#  'plus',
#  'away',
#  'drink',
#  'poli',
#  'wot',
#  'hand',
#  'dude',
#  'top',
#  'hair',
#  'drop',
#  'till',
#  'music',
#  'attempt',
#  'colour',
#  'de',
#  'invit',
#  'beauti',
#  'head',
#  'trip',
#  'oso',
#  'alright',
#  'saw',
#  'xx',
#  'ltdecimalgt',
#  'haf',
#  'yesterday',
#  'food',
#  'doubl',
#  'lei',
#  'onlin',
#  'si',
#  'goin',
#  'club',
#  'open',
#  'hot',
#  'hold',
#  'search',
#  'friendship',
#  'close',
#  'either',
#  'tscs',
#  'sch',
#  'deliveri',
#  'busi',
#  'brother',
#  'ard',
#  'second',
#  'address',
#  'sae',
#  'inform',
#  'stori',
#  'caus',
#  'sad',
#  'famili',
#  'wid',
#  'togeth',
#  'complet',
#  'full',
#  'gr',
#  'bonus',
#  'tot',
#  'no',
#  'player',
#  'mom',
#  'match',
#  'forget',
#  'touch',
#  'train',
#  'old',
#  'noe',
#  'reason',
#  'listen',
#  'huh',
#  'ring',
#  'content',
#  'email',
#  'oki',
#  'murder',
#  'pmsg',
#  'believ',
#  'awesom',
#  'die',
#  'treat',
#  'wil',
#  'hl',
#  'eve',
#  'privat',
#  'mum',
#  'everyon',
#  'coz',
#  'dog',
#  'studi',
#  'took',
#  'park',
#  'anyon',
#  'unsubscrib',
#  'break',
#  'rite',
#  'aft',
#  'mths',
#  'fri',
#  'prob',
#  'simpl',
#  'laugh',
#  'pub',
#  'compani',
#  'sell',
#  'secret',
#  'statement',
#  'card',
#  'sister',
#  'choos',
#  'hard',
#  'kind',
#  'valentin',
#  'download',
#  'expir',
#  'angri',
#  'move',
#  'current',
#  'neva',
#  'congrat',
#  'fanci',
#  'direct',
#  'caller',
#  'forward',
#  'hr',
#  'ta',
#  'mine',
#  'parent',
#  'sort',
#  'alon',
#  'whatev',
#  'seem',
#  'auction',
#  'valu',
#  'lucki',
#  'tho',
#  'isnt',
#  'knw',
#  'am',
#  'sun',
#  'bank',
#  'tomo',
#  'found',
#  'worth',
#  'news',
#  'anytim',
#  'smth',
#  'visit',
#  'ni',
#  'identifi',
#  'ha',
#  'oper',
#  'welcom',
#  'uncl',
#  'surpris',
#  'parti',
#  'pas',
#  'ltd',
#  'unredeem',
#  'log',
#  'frnd',
#  'ticket',
#  'light',
#  'save',
#  'fone',
#  'avail',
#  'joke',
#  'exam',
#  'saturday',
#  'boytoy',
#  'song',
#  'type',
#  'optout',
#  'winner',
#  'far',
#  'outsid',
#  'gd',
#  'bill',
#  'sit',
#  'mobileupd',
#  'colleg',
#  'fast',
#  'return',
#  'crazi',
#  'term',
#  'nt',
#  'cut',
#  'serious',
#  'tea',
#  'mu',
#  'cum',
#  'follow',
#  'wrong',
#  'bday',
#  'case',
#  'bout',
#  'drug',
#  'camcord',
#  'gone',
#  'pretti',
#  'mrng',
#  'sea',
#  'hit',
#  'project',
#  'wit',
#  'nope',
#  'ten',
#  'ad',
#  'oredi',
#  'friday',
#  'rain',
#  'congratul',
#  'carlo',
#  'gal',
#  'scream',
#  'suppos',
#  'least',
#  'remov',
#  'differ',
#  'nyt',
#  'interest',
#  'rock',
#  'kid',
#  'opt',
#  'jay',
#  'snow',
#  'understand',
#  'youll',
#  'info',
#  'unlimit',
#  'wed',
#  'frnds',
#  'cd',
#  'fix',
#  'short',
#  'cours',
#  'correct',
#  'meant',
#  'darlin',
#  'goodmorn',
#  'whole',
#  'tel',
#  'eg',
#  'wq',
#  'hungri',
#  'youv',
#  'confirm',
#  'spend',
#  'wkli',
#  'comput',
#  'hee',
#  'felt',
#  'paper',
#  'fight',
#  'coupl',
#  'usual',
#  'area',
#  'march',
#  'activ',
#  'gas',
#  'almost',
#  'tire',
#  'as',
#  'mah',
#  'marri',
#  'wine',
#  'etc',
#  'near',
#  'joy',
#  'savamob',
#  'sub',
#  'shower',
#  'catch',
#  'yar',
#  'sk',
#  'within',
#  'sex',
#  'press',
#  'luck',
#  'txts',
#  'promis',
#  'dnt',
#  'earlier',
#  'singl',
#  'film',
#  'chennai',
#  'figur',
#  'john',
#  'wasnt',
#  'lost',
#  'fren',
#  'normal',
#  'bslvyl',
#  'fr',
#  'quiz',
#  'knew',
#  'eh',
#  'turn',
#  'side',
#  'motorola',
#  'moment',
#  'nation',
#  'crave',
#  'hospit',
#  'eye',
#  'darren',
#  'store',
#  'grin',
#  'rent',
#  'ipod',
#  'support',
#  'fill',
#  'wow',
#  'freemsg',
#  'load',
#  'max',
#  'ugh',
#  'remind',
#  'truth',
#  'complimentari',
#  'gym',
#  'cheer',
#  'father',
#  'photo',
#  'reward',
#  'extra',
#  'askd',
#  'difficult',
#  'laptop',
#  'slow',
#  'swing',
#  'rental',
#  'chikku',
#  'hell',
#  'seen',
#  'mr',
#  'via',
#  'semest',
#  'ago',
#  'ish',
#  'christma',
#  'connect',
#  'blue',
#  'bcoz',
#  'safe',
#  'abiola',
#  'teach',
#  'slowli',
#  'regist',
#  'kate',
#  'orchard',
#  'noon',
#  'quick',
#  'discount',
#  'idea',
#  'hgsuite',
#  'small',
#  'whenev',
#  'fall',
#  'poor',
#  'link',
#  'copi',
#  'expect',
#  'frm',
#  'lover',
#  'comin',
#  'request',
#  'disturb',
#  'wana',
#  'heard',
#  'usf',
#  'india',
#  'cancel',
#  'muz',
#  'txting',
#  'lovabl',
#  'sim',
#  'fact',
#  'sometim',
#  'silent',
#  'page',
#  'polic',
#  'fantasi',
#  'hmm',
#  'doin',
#  'somebodi',
#  'loan',
#  'comp',
#  'ladi',
#  'hmv',
#  'warm',
#  'wc',
#  'door',
#  'clean',
#  'stand',
#  'deal',
#  'who',
#  'write',
#  'cover',
#  'access',
#  'possibl',
#  'nobodi',
#  'deep',
#  'cup',
#  'ntt',
#  'natur',
#  'la',
#  'weed',
#  'share',
#  'energi',
#  'convey',
#  'immedi',
#  'stupid',
#  'callertun',
#  'sen',
#  'bb',
#  'doctor',
#  'digit',
#  'nah',
#  'definit',
#  'record',
#  'rd',
#  'pete',
#  'regard',
#  'cr',
#  'quot',
#  'otherwis',
#  'forev',
#  'yep',
#  'recent',
#  'trust',
#  'rpli',
#  'voic',
#  'cheap',
#  'ldn',
#  'repres',
#  'wast',
#  'across',
#  'member',
#  'gave',
#  'men',
#  'less',
#  'opinion',
#  'ure',
#  'pray',
#  'style',
#  'water',
#  'monday',
#  'del',
#  'em',
#  'situat',
#  'wap',
#  'mm',
#  'asap',
#  'reveal',
#  'gettin',
#  'met',
#  'england',
#  'ex',
#  'summer',
#  'admir',
#  'glad',
#  'kick',
#  'sick',
#  'apart',
#  'exact',
#  'woke',
#  'clear',
#  'gap',
#  'child',
#  'road',
#  'ho',
#  'oop',
#  'sign',
#  'somewher',
#  'fantast',
#  'excus',
#  'cook',
#  'empti',
#  'med',
#  'especi',
#  'user',
#  'total',
#  'round',
#  'flight',
#  'net',
#  'flirt',
#  'power',
#  'lift',
#  'mark',
#  'hurri',
#  'subscrib',
#  'urself',
#  'thinkin',
#  'basic',
#  'tht',
#  'chariti',
#  'street',
#  'wwwgetzedcouk',
#  'hmmm',
#  'mode',
#  'flag',
#  'app',
#  'list',
#  'norm',
#  'deliv',
#  'result',
#  'merri',
#  'mrt',
#  'bless',
#  'tear',
#  'aint',
#  'indian',
#  'appreci',
#  'std',
#  'sunshin',
#  'bid',
#  'unless',
#  'arriv',
#  'soni',
#  'rest',
#  'wear',
#  'kinda',
#  'lect',
#  'king',
#  'mid',
#  'depend',
#  'hotel',
#  'hiya',
#  'mistak',
#  'accept',
#  'lazi',
#  'ip',
#  'refer',
#  'bx',
#  'bold',
#  'sport',
#  'bluetooth',
#  'xy',
#  'meh',
#  'becom',
#  'rose',
#  'self',
#  'tampa',
#  'add',
#  'sale',
#  'colleagu',
#  'bos',
#  'file',
#  'gay',
#  'gt',
#  'manag',
#  'moon',
#  'slept',
#  'daddi',
#  'lem',
#  'rreveal',
#  'celebr',
#  'respond',
#  'ufind',
#  'mp',
#  'il',
#  'specialcal',
#  'mo',
#  'omg',
#  'medic',
#  'nigeria',
#  'fat',
#  'finger',
#  'inc',
#  'ave',
#  'letter',
#  'wednesday',
#  'btnationalr',
#  'gbp',
#  'bag',
#  'din',
#  'sofa',
#  'respons',
#  'workin',
#  'goodnight',
#  'ppmx',
#  'theyr',
#  'woman',
#  'tonit',
#  'librari',
#  'pleasur',
#  'issu',
#  'experi',
#  'offici',
#  'troubl',
#  'longer',
#  'pc',
#  'facebook',
#  'pictur',
#  'relat',
#  'south',
#  'insid',
#  'entitl',
#  'none',
#  'pwk',
#  'mon',
#  'learn',
#  'goto',
#  'tuesday',
#  'travel',
#  'anymor',
#  'ice',
#  'roww',
#  'com',
#  'wx',
#  'random',
#  ...]

# %%
model.corpus_count
# Out:
# 5567

# %%
model.epochs
# Out:
# 5

# %%
model.wv.similar_by_word('kid')
# Out:
# [('lol', 0.9974920749664307),
#  ('realli', 0.9974381327629089),
#  ('th', 0.997393012046814),
#  ('thank', 0.9973331093788147),
#  ('half', 0.9973282217979431),
#  ('friend', 0.9973078966140747),
#  ('much', 0.9972817301750183),
#  ('went', 0.9972798228263855),
#  ('well', 0.9972671270370483),
#  ('man', 0.9972610473632812)]
